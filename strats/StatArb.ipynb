# %%
import os
os.chdir('/home/mad/statarb')

from pylab import *
from statarb import *
from dataprep import *
from kaufmann import *
from cointegration import *

from baseline import baseline_strategy

data = getdata('BKF', 'EEB').minor_xs('Adj Close')
eq = baseline_strategy(data)
eq.cumsum().plot()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-6d3c75e128a9> in <module>
#       1 import os
# ----> 2 os.chdir('/home/mad/statarb')
#       3
#       4 from pylab import *
#       5 from statarb import *
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/mad/statarb'

# %%
WEIGHTS_ATR_PERIOD = 30
IDX_N = 30
data = getdata('BKF', 'EEB')
eq = kaufmann_strategy(data)
eq.cumsum().plot()

# %%
coint = windowed_coint_test(data['BKF'], data['EEB']).plot()

# %%
data.head()
# Out:
#               BKF    EEB
# Date
# 2007-11-20  51.65  44.24
# 2007-11-21  49.66  41.85
# 2007-11-23  50.35  42.78
# 2007-11-26  48.63  41.46
# 2007-11-27  50.14  42.39

# %%
eq, _ = run_pairslog_strategy(data)                                                               
figsize(15,8)
eq.cumsum().plot()
# Out:
# /usr/local/lib/python2.7/dist-packages/pandas/core/frame.py:3879: FutureWarning: TimeSeries broadcasting along DataFrame index by default is deprecated. Please use DataFrame.<op> to explicitly broadcast arithmetic operations along the index
#   FutureWarning)

# %%
eq, _ = run_kauf_strategy(data)
figsize(15,8)
eq.cumsum().plot()

# %%
ff = getdata_2("AAPL", "MSFT", 14)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-03f3197880f1> in <module>()
# ----> 1 ff = getdata_2("AAPL", "MSFT", 14)
#
# /home/mad/statarb/statarb.pyc in getdata_2(a, b, window)
#      69         a.to_pickle('cache/%s.pickle' % a.name)
#      70         b.to_pickle('cache/%s.pickle' % b.name)
# ---> 71     a = (a["Close"] - pd.rolling_min(a["Low"], window))/(pd.rolling_max(a["High"], window) - pd.rolling_min(a["Low"], window))
#      72     b = (b["Close"] - pd.rolling_min(b["Low"], window))/(pd.rolling_max(b["High"], window) - pd.rolling_min(b["Low"], window))
#      73     zdf = pd.DataFrame([a, b]).T
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/series.pyc in __getitem__(self, key)
#     616     def __getitem__(self, key):
#     617         try:
# --> 618             return self.index.get_value(self, key)
# ...

# %%
a1 = dlp_2('AAPL', 'MSFT')

# %%
data = getdata('BKF', 'EEB').minor_xs('Adj Close')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-ed02379b2621> in <module>()
# ----> 1 data = getdata('BKF', 'EEB').minor_xs('Adj Close')
#
# /home/mad/statarb/dataprep.pyc in getdata(a, b)
#      35         adf.to_pickle('cache/%s.pickle' % a)
#      36         bdf.to_pickle('cache/%s.pickle' % b)
# ---> 37     return pd.Panel({a: adf, b: bdf})
#      38
#      39
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/panel.pyc in __init__(self, data, items, major_axis, minor_axis, copy, dtype)
#     232         self._init_data(
#     233             data=data, items=items, major_axis=major_axis, minor_axis=minor_axis,
# --> 234             copy=copy, dtype=dtype)
#     235
#     236     def _init_data(self, data, copy, dtype, **kwargs):
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/panel.pyc in _init_data(self, data, copy, dtype, **kwargs)
# ...

# %%
adf(data)

# %%
data = getdata('BKF', 'EEB')

# %%
data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1514 entries, 2007-11-20 00:00:00 to 2013-11-22 00:00:00
# Data columns (total 2 columns):
# BKF    1514  non-null values
# EEB    1514  non-null values
# dtypes: float64(2)

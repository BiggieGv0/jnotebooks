# %%
import pandas as pa
from pybacktest.ami_funcs import ExRem
## NOTE: `optstuff` is an .ipynb file.
_run_dbg = False  ## Disable it in the optstuff.ipynb
# %run optstuff.ipynb
#import optstuff
#reload(optstuff)
#from optstuff import *
from IPython.display import HTML
import matplotlib as plt

# %%
pd = (
pa.read_csv(
'/home/mad/Options/SPY_D.csv',
date_parser=lambda v: datetime.datetime.strptime(v, '%d.%m.%Y'),
parse_dates=[0],
).rename(columns=dict(
Date='timestamp', Open='O', High='H', Low='L', Settle='C', Volume='V')
).set_index('timestamp'))
pd['Mean'] = pa.rolling_mean(pd.C, 20)
pd = pd.dropna()
pd['Cond1'] = pd.C > pd.Mean
## Unnecessary
expiration_dates = set(simple_expiration_date(v, skip_days=3) for v in pd.index)
pd['Expiries'] = pd.index.map(lambda v: v in expiration_dates)
pd['Exit'] = pd.Expiries
pd['Buy'] = ExRem(pd.Cond1, pd.Exit)

# %%
H = lambda df: HTML(pd.tail(400).to_html())
tt = H(pd)
#tt

# %%
pd2 = pd.ix[pd.Buy == True]
pd2['Profit'] = 0
pd2 = pd2.copy()
# pd2.Profit.apply(lambda option_profit(symbol='QNG', date = pd.index, price = pd2.C, opt_type='C', distance=5, debug=0, base_active=qng_ba))
# Out:
# -c:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
_res = []
import pdb
import traceback
import sys
for idx in pd2.index:
    row = pd2.ix[idx]
    _p = dict()
    _p1 = _p2 = None
    kwa = dict(
        symbol='SPY',
        date=row.name.date(),  #idx.date(),
        price=Decimal(row.C),
        opt_type='C',
        debug=0,
        return_all=True,
        base_active=pd)
    try:
        _p1 = option_profit(distance=0, direction=1, **kwa)
    except NoData:
        pass
    try:
        _p2 = option_profit(distance=3, direction=-1, **kwa)
    except NoData:
        pass

    if _p1:
        _p.update(
            close_date=_p1['close_date'],
            ba_on_close_price=_p1['ba_on_close'].C,
            ba_on_close_date=_p1['ba_on_close'].name,
            central_strike=_p1['optinfo']['strike'],
            exp_date=_p1['optinfo']['exp_date'],
            central_opt_price=_p1['opt_price'],            
            o1_profit = _p1['profit'],
        )
    if _p2:
        _p.update(
            strike=_p2['optinfo']['strike'],
            opt_price=_p2['opt_price'],
            o2_profit = _p2['profit'],
            close_date_check=_p2['close_date'],
        )
    if _p1 and _p2:
        _p.update(
            profit=_p1['profit'] + _p2['profit'],
        )

    ## option_profit returns:
    ''' return dict(
            profit=profit,
            close_date=close_date,
            optinfo=optinfo,
            opt_a=opt_a,
            opt_b=opt_b,
            ba_on_close=ba_on_close,
            opt_price=opt_price,
        )'''
    _res.append((idx, _p))

_profits = pa.DataFrame([v for k, v in _res], index=[k for k, v in _res])

pd2['close_date'] = _profits['close_date']
pd2['optchain_exp_date'] = _profits['exp_date']
pd2['central_strike'] = _profits['central_strike']
pd2['central_strike_price'] = _profits['central_opt_price']
pd2['central_stike_profit'] = _profits['o1_profit']
pd2['2strike'] = _profits['strike']
pd2['2stike_price'] = _profits['opt_price']
pd2['2stike_profit'] = _profits['o2_profit']
pd2['ba_on_close_price'] = _profits['ba_on_close_price']
pd2['ba_on_close_date'] = _profits['ba_on_close_date']
pd2['sum_profit'] = _profits['profit']

# %%
#_profits.ix['2009-01-01':'2009-12-31':]

# %%
from pandas.io.excel import ExcelWriter
pd3 = pd2.ix['2013-01-01':'2013-12-31':]
pd3 = pd3.drop(['Profit', 'O', 'H', 'L', 'Prev. Day Open Interest', 'Mean', 'Cond1', 'Expiries', 'Exit', ], 1)
H = lambda df: HTML(pd3.head(400).to_html())
tt = H(pd3)
pd3.to_excel('/home/mad/Options/Results/SPY/CBOE_debug_table.xlsx')
tt
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>C</th>
#       <th>V</th>
#       <th>Buy</th>
#       <th>close_date</th>
#       <th>central_strike</th>
#       <th>central_strike_price</th>
#       <th>central_stike_profit</th>
#       <th>2strike</th>
#       <th>2stike_price</th>
#       <th>2stike_profit</th>
#       <th>ba_on_close_price</th>
#       <th>ba_on_close_date</th>
#       <th>sum_profit</th>
#       <th>exp_date</th>
#       <th>optchain_exp_date</th>
#     </tr>
#     <tr>
#       <th>Date</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2013-02-04</th>
#       <td> 156.8200</td>
#       <td> 101504286</td>
#       <td> True</td>
#       <td> 2013-02-16</td>
#       <td> 157.0</td>
#       <td> 0.01</td>
#       <td>-0.010</td>
#       <td> 160.0</td>
#       <td> 0.01</td>
#       <td> 0.010</td>
#       <td> 152.110</td>
#       <td>2013-02-15</td>
#       <td> 0.00</td>
#       <td> 2013-02-16</td>
#       <td> 2013-02-16</td>
#     </tr>
#     <tr>
#       <th>2013-03-05</th>
#       <td> 161.3680</td>
#       <td> 144202220</td>
#       <td> True</td>
#       <td> 2013-03-16</td>
#       <td> 161.0</td>
#       <td> 0.01</td>
#       <td>-0.010</td>
#       <td> 164.0</td>
#       <td> 0.01</td>
#       <td> 0.010</td>
#       <td> 155.830</td>
#       <td>2013-03-15</td>
#       <td> 0.00</td>
#       <td> 2013-03-16</td>
#       <td> 2013-03-16</td>
#     </tr>
#     <tr>
#       <th>2013-04-06</th>
#       <td> 163.5600</td>
#       <td> 157631425</td>
#       <td> True</td>
#       <td> 2013-04-20</td>
#       <td> 164.0</td>
#       <td> 0.01</td>
#       <td>-0.010</td>
#       <td> 167.0</td>
#       <td> 0.01</td>
#       <td> 0.010</td>
#       <td> 155.480</td>
#       <td>2013-04-19</td>
#       <td> 0.00</td>
#       <td> 2013-04-20</td>
#       <td>2013-12-20</td>
#       <td>-0.94</td>
#       <td> 2013-12-21</td>
#       <td> 2013-12-21</td>
#     </tr>
#   </tbody>
# </table>

# %%
'''ba_entry = pd.ix['2013-09-26':].iloc[0]
_r = option_profit(
    symbol='SPY', date=ba_entry.name.date(), price=ba_entry.C, opt_type='C',
    distance=0, debug=3, base_active=pd)
print ""
print _r'''
# Out:
# 'ba_entry = pd.ix[\'2013-09-26\':].iloc[0]\n_r = option_profit(\n    symbol=\'SPY\', date=ba_entry.name.date(), price=ba_entry.C, opt_type=\'C\',\n    distance=0, debug=3, base_active=pd)\nprint ""\nprint _r'

# %%
print OptParserCME().parse(base_dir + 'CME/QNG/QNGX09C3750_D.csv')
print ""
print OptParserCME.load_func(base_dir + 'CME/QNG/QNGX09C3750_D.csv').head(50)
# Out:
# {'load_func': <bound method type.load_func of <class '__main__.OptParserCME'>>, 'symbol': 'QNG', 'opt_type': 'C', 'exp_date': datetime.date(2009, 10, 28), 'strike': 3.75, 'file_path': '/home/mad/Options/CME/QNG/QNGX09C3750_D.csv'}
#
#                O      H     L      C   V   OI
# timestamp
# 2009-09-03  0.45  0.455  0.44  0.394  14  200
# 2009-09-04  0.35  0.350  0.35  0.440   1  314
# 2009-09-08  0.46  0.460  0.46  0.500   1  321

# %%
ec??

# %%
from pyquant.equity.equity import EquityCurve
ec = EquityCurve()
for timestamp, value in pd3.sum_profit.iteritems():
    # print "ts %r val %r" % (timestamp, value)
    ec.add_change(timestamp, value)

ec.statistics()
# Out:
# {'average': -0.12,
#  'final_equity': -0.75,
#  'maxdd': 1.69,
#  'mean_loss': -0.91,
#  'mean_profit': 0.66,
#  'median': -0.02,
#  'median_loss': -0.94,
#  'median_profit': 0.24,
#  'payoff_ratio': 0.72,
#  'points': 6,
#  'profit_factor': 0.72,
#  'sd': 1.05,
#  'sd_losses': 0.65,
#  'sd_profits': 0.74,
#  'sharpe': -0.12,
#  'sortino': -0.19,
#  'winrate': 0.5}

# %%
from pybacktest.performance import performance_summary
performance_summary(pd3.sum_profit)
# Out:
# {'backtest': {'days': 174,
#   'from': '2013-06-08 00:00:00',
#   'to': '2013-11-29 00:00:00',
#   'trades': 6},
#  'exposure': {'trades/month': 1.2},
#  'performance': {'PF': 0.7243,
#   'RF': -0.4438,
#   'averages': {'gain': 0.6567, 'loss': -0.9067, 'trade': -0.125},
#   'payoff': 0.7243,
#   'profit': -0.75,
#   'winrate': 0.5},
#  'risk/return profile': {'MPI': -0.1898,
#   'UPI': -0.1582,
#   'WCDD (monte-carlo 0.99 quantile)': 2.72,
#   'maxdd': 1.69,
#   'sharpe': -0.1091,
#   'sortino': -0.1561}}

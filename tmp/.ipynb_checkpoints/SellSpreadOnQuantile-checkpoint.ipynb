# %%
import pandas as pa
from pybacktest.ami_funcs import ExRem
## NOTE: `optstuff` is an .ipynb file.
_run_dbg = False  ## Disable it in the optstuff.ipynb
# %run optstuff.ipynb
#import optstuff
#reload(optstuff)
#from optstuff import *
from IPython.display import HTML
import matplotlib as plt
#from pandas.io.excel import ExcelWriter

# %%
#Data loading
ba = (
    pa.read_csv(
        '/home/mad/Options/SPY_D.csv',
        date_parser=lambda v: datetime.datetime.strptime(v, '%d.%m.%Y'),
        parse_dates=[0],
    ).rename(columns=dict(
        Date='timestamp', Open='O', High='H', Low='L', Settle='C', Volume='V')
    ).set_index('timestamp'))
ba = ba.drop(['Prev. Day Open Interest', 'V'], 1)

# %%
#[(
#   v,
#   simple_expiration_date(v, from_last_month_day=False, skip_days=3, debug=3),
#)
#    for v in list(ba_cut.index)[:4]]

# %%
#BA strategy
ba['volat'] = (ba.H - ba.L)/ba.C

"""
Percent Range
"""

def decil(rang, val):
    total = bigger = 0
    for x in rang:
        total += 1
        if x <= val:
            bigger += 1
    decil = float(bigger)/total
    return decil

def fta(series):
    return decil(series[:-1], series[-1])

ba['Decile'] = pa.rolling_apply(ba.volat, 50, fta)
#ba['PreVol'] = pa.rolling_mean(ba.volat, 5)
#ba['PostVol'] = pa.rolling_mean(ba.volat.shift(-5), 5)

#ba['VolaRelation'] = np.log(ba['PostVol'] / ba['PreVol'])
ba['Buy'] = (ba.Decile >= 0) & (ba.Decile < 0.1)
#ba_cut = ba.ix['2012-01-01':]
#going to next days Open 
#expiration_dates = set(
#    simple_expiration_date(v, from_last_month_day=False, skip_days=3)
#    for v in ba_cut.index)
#ba['Expiries'] = ba.index.map(lambda v: v in expiration_dates)
#ba['Exit'] = ba.Expiries
#ba['Buy'] = ExRem(ba.Cond1, ba.Exit)
#ba.ix['2013-12-01':]


#def PostVolat(current index, target index):
#    for i in index range:
#        calc of mean
#    return mean

# %%
#Filtering only buy signals
pd2 = ba.copy()
pd2['Profit'] = 0
pd2 = pd2.ix['2012-01-01':'2015-01-01']
#pd2.ix['2014-09-01':'2014-11-01']

# %%
#Options strategy
_res = []
import functools
option_profit_my = functools.partial(option_profit, midstrike_rounding='by_type')
import pdb
import traceback
import sys


def optprofit2data(optprofit_ret, prefix=''):
    if not optprofit_ret:
        return dict()
    res = dict(
        strike=optprofit_ret['optinfo']['strike'],
        price=optprofit_ret['opt_price'],
        profit=optprofit_ret['profit'],
    )
    if prefix:
        res = {'%s%s' % (prefix, k): v for k, v in res.items()}
    return res


debug = 3

#relevant_index = [pd2.ix['2013-12-30':].index[0]]
#  Normally:
relevant_index = pd2.index

for idx in relevant_index:
    row = pd2.ix[idx]
    if not row['Buy']:
        continue
    try:
        next_day = pd2.shift(-1).ix[idx]
    except KeyError:
        print "No next day for %r" % (idx,)
        continue
    if debug >= 3:
        print "\nidx:", idx
        print "\nrow:", row.to_dict()
        print "\nnext_day:", next_day.to_dict()
        print "\n"
    price = Decimal(next_day.O)
    _p = dict(
        price=price,
    )
    _p1 = _p2 = _p3 = _p4 = None
    kwa = dict(
        symbol='SPY',
        date=row.name.date(),  #idx.date(),
        price=price,
        debug=debug,
        return_all=True,
        base_active=ba
    )
    try:
        _p1 = option_profit_my(distance=0, direction=-1, opt_type='C', **kwa)
        _p2 = option_profit_my(distance=4, direction=1, opt_type='C', **kwa)
        _p3 = option_profit_my(distance=0, direction=-1, opt_type='P', **kwa)
        _p4 = option_profit_my(distance=-4, direction=1, opt_type='P', **kwa)
    except NoData as exc:
        print "NoData at %r: %r" % (idx, exc)
        continue

    _p.update(
        close_date=_p1['close_date'],
        ba_close_price=_p1['ba_on_close'].C,
        ba_on_close_date=_p1['ba_on_close'].name,
    )
    _p.update(optprofit2data(_p1, prefix='o1_'))
    _p.update(optprofit2data(_p2, prefix='o2_'))
    _p.update(optprofit2data(_p3, prefix='o3_'))
    _p.update(optprofit2data(_p4, prefix='o4_'))

    if _p1 and _p2 and _p3 and _p4:
        _p.update(
            profit=_p1['profit'] + _p2['profit'] + _p3['profit'] + _p4['profit'],
        )

    if debug >= 3:
        print "\nres line:", _p
    _res.append((idx, _p))

print "I: results length: %r" % (len(_res),)
_profits = pa.DataFrame([v for k, v in _res], index=[k for k, v in _res])

pd2['close_date'] = _profits['close_date']
pd2['ba_on_close'] = _profits['ba_close_price']
#pd2['req_strike_price'] = _profits['price']
pd2['call_ATM_strike'] = _profits['o1_strike']
pd2['call_ATM_price'] = _profits['o1_price']
pd2['call_ATM_profit'] = _profits['o1_profit']
pd2['call_OTM_strike'] = _profits['o2_strike']
pd2['call_OTM_price'] = _profits['o2_price']
pd2['call_OTM_profit'] = _profits['o2_profit']
pd2['put_ATM_strike'] = _profits['o3_strike']
pd2['put_ATM_price'] = _profits['o3_price']
pd2['put_ATM_profit'] = _profits['o3_profit']
pd2['put_OTM_strike'] = _profits['o4_strike']
pd2['put_OTM_price'] = _profits['o4_price']
pd2['put_OTM_profit'] = _profits['o4_profit']
pd2['sum_profit'] = _profits['profit']
# Out:
# idx: 2012-01-03 00:00:00
#
# row: {'C': 127.495, 'Buy': True, 'Profit': 0, 'H': 128.38, 'L': 127.43000000000001, 'Decile': 0.040816326530612242, 'volat': 0.0074512725989253582, 'O': 127.76000000000001}
#
# next_day: {'C': 127.7, 'Buy': False, 'Profit': 0.0, 'H': 127.81, 'L': 126.70999999999999, 'Decile': 0.10204081632653061, 'volat': 0.0086139389193422757, 'O': 127.2}
#
#
# I: selected option with expiry datetime.date(2012, 1, 6)
# D: round_func: <function nearest_higher at 0x47b9c80>
# I: rounding the strike from 127.2 to 128.0
# D: lower_strikes: [127.0, 126.0, 125.0, 124.0, 123.0, 122.0, 121.0, 120.0, 119.0]
# D: matching_strikes: [128.0]
# D: higher_strikes: [129.0, 130.0, 131.0, 132.0, 133.0, 134.0]
# loading file: /home/mad/Options/CBOE/SPY/Weekly/SPY1206A128_D.csv
# fileinfo: {'load_func': <bound method type.load_func of <class '__main__.OptParserCBOE'>>, 'symbol': 'SPY', 'opt_type': 'C', 'exp_date': datetime.date(2012, 1, 6), 'strike': 128.0, 'file_path': '/home/mad/Options/CBOE/SPY/Weekly/SPY1206A128_D.csv'}
# data dates: <class 'pandas.tseries.index.DatetimeIndex'>
# [2011-12-29, ..., 2012-01-06]
# Length: 6, Freq: None, Timezone: None
# business day: 2012-01-04
# opt_strike:  128.0
# opt_price:  0.46
# ba_price:  127.71
# opt profit:  0.0
# I: selected option with expiry datetime.date(2012, 1, 6)
# D: round_func: <function nearest_higher at 0x47b9c80>
# I: rounding the strike from 127.2 to 128.0
# D: lower_strikes: [127.0, 126.0, 125.0, 124.0, 123.0, 122.0, 121.0, 120.0, 119.0]
# D: matching_strikes: [128.0]
# D: higher_strikes: [129.0, 130.0, 131.0, 132.0, 133.0, 134.0]
# loading file: /home/mad/Options/CBOE/SPY/Weekly/SPY1206A132_D.csv
# fileinfo: {'load_func': <bound method type.load_func of <class '__main__.OptParserCBOE'>>, 'symbol': 'SPY', 'opt_type': 'C', 'exp_date': datetime.date(2012, 1, 6), 'strike': 132.0, 'file_path': '/home/mad/Options/CBOE/SPY/Weekly/SPY1206A132_D.csv'}
# data dates: <class 'pandas.tseries.index.DatetimeIndex'>
# [2011-12-29, ..., 2012-01-06]
# Length: 6, Freq: None, Timezone: None
# business day: 2012-01-04
# opt_strike:  132.0
# opt_price:  0.02
# ba_price:  127.71
# opt profit:  0.0
# I: selected option with expiry datetime.date(2012, 1, 6)
# D: round_func: <function nearest_lower at 0x47b9f50>
# I: rounding the strike from 127.2 to 127.0
# D: lower_strikes: [126.0, 125.0, 124.0, 123.0, 122.0, 121.0, 120.0, 119.0, 118.0]
# D: matching_strikes: [127.0]
# D: higher_strikes: [128.0, 129.0, 130.0, 131.0, 132.0, 133.0, 134.0]
# loading file: /home/mad/Options/CBOE/SPY/Weekly/SPY1206M127_D.csv
# fileinfo: {'load_func': <bound method type.load_func of <class '__main__.OptParserCBOE'>>, 'symbol': 'SPY', 'opt_type': 'P', 'exp_date': datetime.date(2012, 1, 6), 'strike': 127.0, 'file_path': '/home/mad/Options/CBOE/SPY/Weekly/SPY1206M127_D.csv'}
# data dates: <class 'pandas.tseries.index.DatetimeIndex'>
# [2011-12-29, ..., 2012-01-06]
# Length: 6, Freq: None, Timezone: None
# business day: 2012-01-04
# opt_strike:  127.0
# opt_price:  0.75
# ba_price:  127.71
# opt profit:  0.71
# I: selected option with expiry datetime.date(2012, 1, 6)
# D: round_func: <function nearest_lower at 0x47b9f50>
# I: rounding the strike from 127.2 to 127.0
# D: lower_strikes: [126.0, 125.0, 124.0, 123.0, 122.0, 121.0, 120.0, 119.0, 118.0]
# D: matching_strikes: [127.0]
# D: higher_strikes: [128.0, 129.0, 130.0, 131.0, 132.0, 133.0, 134.0]
# loading file: /home/mad/Options/CBOE/SPY/Weekly/SPY1206M121_D.csv
# fileinfo: {'load_func': <bound method type.load_func of <class '__main__.OptParserCBOE'>>, 'symbol': 'SPY', 'opt_type': 'P', 'exp_date': datetime.date(2012, 1, 6), 'strike': 121.0, 'file_path': '/home/mad/Options/CBOE/SPY/Weekly/SPY1206M121_D.csv'}
# data dates: <class 'pandas.tseries.index.DatetimeIndex'>
# [2011-12-29, ..., 2012-01-06]
# Length: 6, Freq: None, Timezone: None
# business day: 2012-01-04
# opt_strike:  121.0
# opt_price:  0.02
# ba_price:  127.71
# opt profit:  6.71
#
# res line: {'o3_price': 0.75, 'o1_strike': 128.0, 'o4_profit': -0.02, 'o2_price': 0.02, 'ba_close_price': 127.70999999999999, 'ba_on_close_date': Timestamp('2012-01-06 00:00:00'), 'profit': 1.1699999999999999, 'price': Decimal('127.2000000000000028421709430404007434844970703125'), 'o4_price': 0.02, 'o3_profit': 0.75, 'o3_strike': 127.0, 'o4_strike': 121.0, 'o1_profit': 0.46000000000000002, 'close_date': datetime.date(2012, 1, 6), 'o1_price': 0.46000000000000002, 'o2_strike': 132.0, 'o2_profit': -0.02}
#
# idx: 2012-01-06 00:00:00
#
# row: {'C': 127.70999999999999, 'Buy': True, 'Profit': 0, 'H': 128.22, 'L': 127.29000000000001, 'Decile': 0.040816326530612242, 'volat': 0.0072821235611932713, 'O': 128.19999999999999}
#
# next_day: {'C': 128.02000000000001, 'Buy': True, 'Profit': 0.0, 'H': 128.18000000000001, 'L': 127.41, 'Decile': 0.020408163265306121, 'volat': 0.0060146852054367298, 'O': 128.0}
#
#
# I: selected option with expiry datetime.date(2012, 1, 13)
# D: lower_strikes: [127.0, 126.0, 125.0, 124.0, 123.0, 122.0, 121.0, 120.0, 119.0]
# D: matching_strikes: [128.0]
# D: higher_strikes: [129.0, 130.0, 131.0, 132.0, 133.0, 134.0, 135.0, 136.0, 137.0]
# loading file: /home/mad/Options/CBOE/SPY/Weekly/SPY1213A128_D.csv
# fileinfo: {'load_func': <bound method type.load_func of <class '__main__.OptParserCBOE'>>, 'symbol': 'SPY', 'opt_type': 'C', 'exp_date': datetime.date(2012, 1, 13), 'strike': 128.0, 'file_path': '/home/mad/Options/CBOE/SPY/Weekly/SPY1213A128_D.csv'}
# data dates: <class 'pandas.tseries.index.DatetimeIndex'>
# [2012-01-05, ..., 2012-01-13]
# Length: 7, Freq: None, Timezone: None
# weekend (Saturday): 2012-01-07
# weekend (Sunday): 2012-01-08
# business day: 2012-01-09
# opt_strike:  128.0
# opt_price:  1.03
# ba_price:  128.84
# opt profit:  0.84
# I: selected option with expiry datetime.date(2012, 1, 13)
# D: lower_strikes: [127.0, 126.0, 125.0, 124.0, 123.0, 122.0, 121.0, 120.0, 119.0]
# D: matching_strikes: [128.0]
# D: higher_strikes: [129.0, 130.0, 131.0, 132.0, 133.0, 134.0, 135.0, 136.0, 137.0]
# loading file: /home/mad/Options/CBOE/SPY/Weekly/SPY1213A132_D.csv
# fileinfo: {'load_func': <bound method type.load_func of <class '__main__.OptParserCBOE'>>, 'symbol': 'SPY', 'opt_type': 'C', 'exp_date': datetime.date(2012, 1, 13), 'strike': 132.0, 'file_path': '/home/mad/Options/CBOE/SPY/Weekly/SPY1213A132_D.csv'}
# data dates: <class 'pandas.tseries.index.DatetimeIndex'>
# [2012-01-05, ..., 2012-01-13]
# Length: 7, Freq: None, Timezone: None
# weekend (Saturday): 2012-01-07
# weekend (Sunday): 2012-01-08
# business day: 2012-01-09
# opt_strike:  132.0
# opt_price:  0.03
# ba_price:  128.84
# opt profit:  0.0
# I: selected option with expiry datetime.date(2012, 1, 13)
# D: lower_strikes: [127.0, 126.0, 125.0, 124.0, 123.0, 122.0, 121.0, 120.0, 119.0]
# D: matching_strikes: [128.0]
# D: higher_strikes: [129.0, 130.0, 131.0, 132.0, 133.0, 134.0, 135.0, 136.0, 137.0]
# loading file: /home/mad/Options/CBOE/SPY/Weekly/SPY1213M128_D.csv
# fileinfo: {'load_func': <bound method type.load_func of <class '__main__.OptParserCBOE'>>, 'symbol': 'SPY', 'opt_type': 'P', 'exp_date': datetime.date(2012, 1, 13), 'strike': 128.0, 'file_path': '/home/mad/Options/CBOE/SPY/Weekly/SPY1213M128_D.csv'}
# data dates: <class 'pandas.tseries.index.DatetimeIndex'>
# [2012-01-05, ..., 2012-01-13]
# Length: 7, Freq: None, Timezone: None
# weekend (Saturday): 2012-01-07
# weekend (Sunday): 2012-01-08
# business day: 2012-01-09
# opt_strike:  128.0
# opt_price:  1.11
# ba_price:  128.84
# opt profit:  0.84
# I: selected option with expiry datetime.date(2012, 1, 13)
# D: lower_strikes: [127.0, 126.0, 125.0, 124.0, 123.0, 122.0, 121.0, 120.0, 119.0]
# D: matching_strikes: [128.0]
# D: higher_strikes: [129.0, 130.0, 131.0, 132.0, 133.0, 134.0, 135.0, 136.0, 137.0]
# loading file: /home/mad/Options/CBOE/SPY/Weekly/SPY1213M122_D.csv
# fileinfo: {'load_func': <bound method type.load_func of <class '__main__.OptParserCBOE'>>, 'symbol': 'SPY', 'opt_type': 'P', 'exp_date': datetime.date(2012, 1, 13), 'strike': 122.0, 'file_path': '/home/mad/Options/CBOE/SPY/Weekly/SPY1213M122_D.csv'}
# data dates: <class 'pandas.tseries.index.DatetimeIndex'>
# [2012-01-05, ..., 2012-01-13]
# Length: 7, Freq: None, Timezone: None
# weekend (Saturday): 2012-01-07
# weekend (Sunday): 2012-01-08
# business day: 2012-01-09
# opt_strike:  122.0
# opt_price:  0.1
# ba_price:  128.84
# opt profit:  6.84
#
# res line: {'o3_price': 1.1100000000000001, 'o1_strike': 128.0, 'o4_profit': -0.10000000000000001, 'o2_price': 0.029999999999999999, 'ba_close_price': 128.84, 'ba_on_close_date': Timestamp('2012-01-13 00:00:00'), 'profit': 1.1699999999999966, 'price': Decimal('128'), 'o4_price': 0.10000000000000001, 'o3_profit': 1.1100000000000001, 'o3_strike': 128.0, 'o4_strike': 122.0, 'o1_profit': 0.18999999999999662, 'close_date': datetime.date(2012, 1, 13), 'o1_price': 1.03, 'o2_strike': 132.0, 'o2_profit': -0.029999999999999999}
#
# idx: 2012-01-09 00:00:00
#
# row: {'C': 128.02000000000001, 'Buy': True, 'Profit': 0, 'H': 128.18000000000001, 'L': 127.41, 'Decile': 0.020408163265306121, 'volat': 0.0060146852054367298, 'O': 128.0}
#
# next_day: {'C': 129.13, 'Buy': True, 'Profit': 0.0, 'H': 129.65000000000001, 'L': 128.94999999999999, 'Decile': 0.0, 'volat': 0.0054208936730428025, 'O': 129.38999999999999}
#
#
# I: selected option with expiry datetime.date(2012, 1, 13)
# D: round_func: <function nearest_higher at 0x47b9c80>
# I: rounding the strike from 129.39 to 130.0
# D: lower_strikes: [129.0, 128.0, 127.0, 126.0, 125.0, 124.0, 123.0, 122.0, 121.0]
# D: matching_strikes: [130.0]
# D: higher_strikes: [131.0, 132.0, 133.0, 134.0, 135.0, 136.0, 137.0]
# loading file: /home/mad/Options/CBOE/SPY/Weekly/SPY1213A130_D.csv
# fileinfo: {'load_func': <bound method type.load_func of <class '__main__.OptParserCBOE'>>, 'symbol': 'SPY', 'opt_type': 'C', 'exp_date': datetime.date(2012, 1, 13), 'strike': 130.0, 'file_path': '/home/mad/Options/CBOE/SPY/Weekly/SPY1213A130_D.csv'}
# data dates: <class 'pandas.tseries.index.DatetimeIndex'>
# [2012-01-05, ..., 2012-01-13]
# Length: 7, Freq: None, Timezone: None
# business day: 2012-01-10
# opt_strike:  130.0
# opt_price:  0.55
# ba_price:  128.84
# opt profit:  0.0
# I: selected option with expiry datetime.date(2012, 1, 13)
# D: round_func: <function nearest_higher at 0x47b9c80>
# I: rounding the strike from 129.39 to 130.0
# D: lower_strikes: [129.0, 128.0, 127.0, 126.0, 125.0, 124.0, 123.0, 122.0, 121.0]
# D: matching_strikes: [130.0]
# D: higher_strikes: [131.0, 132.0, 133.0, 134.0, 135.0, 136.0, 137.0]
# loading file: /home/mad/Options/CBOE/SPY/Weekly/SPY1213A134_D.csv
# fileinfo: {'load_func': <bound method type.load_func of <class '__main__.OptParserCBOE'>>, 'symbol': 'SPY', 'opt_type': 'C', 'exp_date': datetime.date(2012, 1, 13), 'strike': 134.0, 'file_path': '/home/mad/Options/CBOE/SPY/Weekly/SPY1213A134_D.csv'}
# data dates: <class 'pandas.tseries.index.DatetimeIndex'>
# [2012-01-05, ..., 2012-01-12]
# Length: 6, Freq: None, Timezone: None
# business day: 2012-01-10
# opt_strike:  134.0
# opt_price:  0.02
# ba_price:  128.84
# opt profit:  0.0
# I: selected option with expiry datetime.date(2012, 1, 13)
# D: round_func: <function nearest_lower at 0x47b9f50>
# I: rounding the strike from 129.39 to 129.0
# D: lower_strikes: [128.0, 127.0, 126.0, 125.0, 124.0, 123.0, 122.0, 121.0, 120.0]
# D: matching_strikes: [129.0]
# D: higher_strikes: [130.0, 131.0, 132.0, 133.0, 134.0, 135.0, 136.0, 137.0]
# loading file: /home/mad/Options/CBOE/SPY/Weekly/SPY1213M129_D.csv
# fileinfo: {'load_func': <bound method type.load_func of <class '__main__.OptParserCBOE'>>, 'symbol': 'SPY', 'opt_type': 'P', 'exp_date': datetime.date(2012, 1, 13), 'strike': 129.0, 'file_path': '/home/mad/Options/CBOE/SPY/Weekly/SPY1213M129_D.csv'}
# data dates: <class 'pandas.tseries.index.DatetimeIndex'>
# [2012-01-05, ..., 2012-01-13]
# Length: 7, Freq: None, Timezone: None
# business day: 2012-01-10
# opt_strike:  129.0
# opt_price:  0.6
# ba_price:  128.84
# opt profit:  0.0
# I: selected option with expiry datetime.date(2012, 1, 13)
# D: round_func: <function nearest_lower at 0x47b9f50>
# I: rounding the strike from 129.39 to 129.0
# D: lower_strikes: [128.0, 127.0, 126.0, 125.0, 124.0, 123.0, 122.0, 121.0, 120.0]
# D: matching_strikes: [129.0]
# D: higher_strikes: [130.0, 131.0, 132.0, 133.0, 134.0, 135.0, 136.0, 137.0]
# loading file: /home/mad/Options/CBOE/SPY/Weekly/SPY1213M123_D.csv
# fileinfo: {'load_func': <bound method type.load_func of <class '__main__.OptParserCBOE'>>, 'symbol': 'SPY', 'opt_type': 'P', 'exp_date': datetime.date(2012, 1, 13), 'strike': 123.0, 'file_path': '/home/mad/Options/CBOE/SPY/Weekly/SPY1213M123_D.csv'}
# data dates: <class 'pandas.tseries.index.DatetimeIndex'>
# [2012-01-05, ..., 2012-01-13]
# Length: 7, Freq: None, Timezone: None
# business day: 2012-01-10
# opt_strike:  123.0
# opt_price:  0.01
# ba_price:  128.84
# opt profit:  5.84
#
# res line: {'o3_price': 0.59999999999999998, 'o1_strike': 130.0, 'o4_profit': -0.01, 'o2_price': 0.02, 'ba_close_price': 128.84, 'ba_on_close_date': Timestamp('2012-01-13 00:00:00'), 'profit': 0.96000000000000341, 'price': Decimal('129.3899999999999863575794734060764312744140625'), 'o4_price': 0.01, 'o3_profit': 0.44000000000000339, 'o3_strike': 129.0, 'o4_strike': 123.0, 'o1_profit': 0.55000000000000004, 'close_date': datetime.date(2012, 1, 13), 'o1_price': 0.55000000000000004, 'o2_strike': 134.0, 'o2_profit': -0.02}
#
# idx: 2012-01-10 00:00:00
#
# row: {'C': 129.13, 'Buy': True, 'Profit': 0, 'H': 129.65000000000001, 'L': 128.94999999999999, 'Decile': 0.0, 'volat': 0.0054208936730428025, 'O': 129.38999999999999}
#
# next_day: {'C': 129.19999999999999, 'Buy': True, 'Profit': 0.0, 'H': 129.37, 'L': 128.52000000000001, 'Decile': 0.061224489795918366, 'volat': 0.0065789473684210089, 'O': 128.72999999999999}
#
#
# I: selected option with expiry datetime.date(2012, 1, 13)
# D: round_func: <function nearest_higher at 0x47b9c80>
# I: rounding the strike from 128.73 to 129.0
# D: lower_strikes: [128.0, 127.0, 126.0, 125.0, 124.0, 123.0, 122.0, 121.0, 120.0]
# D: matching_strikes: [129.0]
# D: higher_strikes: [130.0, 131.0, 132.0, 133.0, 134.0, 135.0, 136.0, 137.0]
# loading file: /home/mad/Options/CBOE/SPY/Weekly/SPY1213A129_D.csv
# fileinfo: {'load_func': <bound method type.load_func of <class '__main__.OptParserCBOE'>>, 'symbol': 'SPY', 'opt_type': 'C', 'exp_date': datetime.date(2012, 1, 13), 'strike': 129.0, 'file_path': '/home/mad/Options/CBOE/SPY/Weekly/SPY1213A129_D.csv'}
# data dates: <class 'pandas.tseries.index.DatetimeIndex'>
# [2012-01-05, ..., 2012-01-13]
# Length: 7, Freq: None, Timezone: None
# business day: 2012-01-11
# opt_strike:  129.0
# opt_price:  0.56
# ba_price:  128.84
# opt profit:  0.0
# I: selected option with expiry datetime.date(2012, 1, 13)
# D: round_func: <function nearest_higher at 0x47b9c80>
# I: rounding the strike from 128.73 to 129.0
# D: lower_strikes: [128.0, 127.0, 126.0, 125.0, 124.0, 123.0, 122.0, 121.0, 120.0]
# D: matching_strikes: [129.0]
# D: higher_strikes: [130.0, 131.0, 132.0, 133.0, 134.0, 135.0, 136.0, 137.0]
# loading file: /home/mad/Options/CBOE/SPY/Weekly/SPY1213A133_D.csv
# fileinfo: {'load_func': <bound method type.load_func of <class '__main__.OptParserCBOE'>>, 'symbol': 'SPY', 'opt_type': 'C', 'exp_date': datetime.date(2012, 1, 13), 'strike': 133.0, 'file_path': '/home/mad/Options/CBOE/SPY/Weekly/SPY1213A133_D.csv'}
# data dates: <class 'pandas.tseries.index.DatetimeIndex'>
# [2012-01-05, ..., 2012-01-13]
# Length: 7, Freq: None, Timezone: None
# business day: 2012-01-11
# opt_strike:  133.0
# opt_price:  0.01
# ba_price:  128.84
# opt profit:  0.0
# I: selected option with expiry datetime.date(2012, 1, 13)
# D: round_func: <function nearest_lower at 0x47b9f50>
# I: rounding the strike from 128.73 to 128.0
# D: lower_strikes: [127.0, 126.0, 125.0, 124.0, 123.0, 122.0, 121.0, 120.0, 119.0]
# D: matching_strikes: [128.0]
# D: higher_strikes: [129.0, 130.0, 131.0, 132.0, 133.0, 134.0, 135.0, 136.0, 137.0]
# loading file: /home/mad/Options/CBOE/SPY/Weekly/SPY1213M128_D.csv
# fileinfo: {'load_func': <bound method type.load_func of <class '__main__.OptParserCBOE'>>, 'symbol': 'SPY', 'opt_type': 'P', 'exp_date': datetime.date(2012, 1, 13), 'strike': 128.0, 'data':                O     H     L     C       V     OI
# timestamp
# 2012-01-05  1.86  2.15  1.18  1.41    8789   7867
# 2012-01-06  1.15  1.58  1.05  1.17   31061  20482
# 2012-01-09  1.11  1.29  0.81  0.87   30960  24942
# 2012-01-10  0.39  0.43  0.26  0.39   24989  30499
# 2012-01-11  0.41  0.50  0.19  0.21   43464  39481
# 2012-01-12  0.15  0.31  0.04  0.05   60699  58920
# 2012-01-13  0.13  0.52  0.01  0.01  167332  68904, 'file_path': '/home/mad/Options/CBOE/SPY/Weekly/SPY1213M128_D.csv'}
# data dates: <class 'pandas.tseries.index.DatetimeIndex'>
# [2012-01-05, ..., 2012-01-13]
# Length: 7, Freq: None, Timezone: None
# business day: 2012-01-11
# opt_strike:  128.0
# opt_price:  0.41
# ba_price:  128.84
# opt profit:  0.84
# I: selected option with expiry datetime.date(2012, 1, 13)
# D: round_func: <function nearest_lower at 0x47b9f50>
# I: rounding the strike from 128.73 to 128.0
# D: lower_strikes: [127.0, 126.0, 125.0, 124.0, 123.0, 122.0, 121.0, 120.0, 119.0]
# D: matching_strikes: [128.0]
# D: higher_strikes: [129.0, 130.0, 131.0, 132.0, 133.0, 134.0, 135.0, 136.0, 137.0]
# loading file: /home/mad/Options/CBOE/SPY/Weekly/SPY1213M122_D.csv
# fileinfo: {'load_func': <bound method type.load_func of <class '__main__.OptParserCBOE'>>, 'symbol': 'SPY', 'opt_type': 'P', 'exp_date': datetime.date(2012, 1, 13), 'strike': 122.0, 'data':                O     H     L     C      V     OI
# timestamp
# 2012-01-05  0.23  0.30  0.12  0.14   4079   3403
# 2012-01-06  0.12  0.14  0.08  0.10  12496  12871
# 2012-01-09  0.10  0.10  0.04  0.04   3855  15909
# 2012-01-10  0.03  0.03  0.01  0.02   1824  16416
# 2012-01-11  0.02  0.02  0.01  0.01   3888  17779
# 2012-01-12  0.01  0.01  0.01  0.01    205  17832
# 2012-01-13  0.01  0.01  0.01  0.01     10  17834, 'file_path': '/home/mad/Options/CBOE/SPY/Weekly/SPY1213M122_D.csv'}
# data dates: <class 'pandas.tseries.index.DatetimeIndex'>
# [2012-01-05, ..., 2012-01-13]
# Length: 7, Freq: None, Timezone: None
# business day: 2012-01-11
# opt_strike:  122.0
# opt_price:  0.02
# ba_price:  128.84
# opt profit:  6.84
#
# res line: {'o3_price': 0.40999999999999998, 'o1_strike': 129.0, 'o4_profit': -0.02, 'o2_price': 0.01, 'ba_close_price': 128.84, 'ba_on_close_date': Timestamp('2012-01-13 00:00:00'), 'profit': 0.93999999999999995, 'price': Decimal('128.729999999999989768184605054557323455810546875'), 'o4_price': 0.02, 'o3_profit': 0.40999999999999998, 'o3_strike': 128.0, 'o4_strike': 122.0, 'o1_profit': 0.56000000000000005, 'close_date': datetime.date(2012, 1, 13), 'o1_price': 0.56000000000000005, 'o2_strike': 133.0, 'o2_profit': -0.01}
#
# idx: 2012-01-11 00:00:00
#
# row: {'C': 129.19999999999999, 'Buy': True, 'Profit': 0, 'H': 129.37, 'L': 128.52000000000001, 'Decile': 0.061224489795918366, 'volat': 0.0065789473684210089, 'O': 128.72999999999999}
#
# next_day: {'C': 129.50999999999999, 'Buy': False, 'Profit': 0.0, 'H': 129.69999999999999, 'L': 128.53999999999999, 'Decile': 0.18367346938775511, 'volat': 0.0089568373098602161, 'O': 129.56999999999999}
#
#
# I: selected option with expiry datetime.date(2012, 1, 13)
# D: round_func: <function nearest_higher at 0x47b9c80>
# I: rounding the strike from 129.57 to 130.0
# D: lower_strikes: [129.0, 128.0, 127.0, 126.0, 125.0, 124.0, 123.0, 122.0, 121.0]
# D: matching_strikes: [130.0]
# D: higher_strikes: [131.0, 132.0, 133.0, 134.0, 135.0, 136.0, 137.0]
# loading file: /home/mad/Options/CBOE/SPY/Weekly/SPY1213A130_D.csv
# fileinfo: {'load_func': <bound method type.load_func of <class '__main__.OptParserCBOE'>>, 'symbol': 'SPY', 'opt_type': 'C', 'exp_date': datetime.date(2012, 1, 13), 'strike': 130.0, 'data':                O     H     L     C      V     OI
# timestamp
# 2012-01-05  0.27  0.48  0.22  0.39   4443   3582
# 2012-01-06  0.46  0.46  0.25  0.30  12434  10473
# 2012-01-09  0.26  0.28  0.15  0.17  14259  18816
# 2012-01-10  0.55  0.60  0.33  0.36  36621  25813
# 2012-01-11  0.21  0.33  0.18  0.30  32850  35146
# 2012-01-12  0.36  0.39  0.08  0.25  60281  38159
# 2012-01-13  0.05  0.05  0.01  0.01  22927  36103, 'file_path': '/home/mad/Options/CBOE/SPY/Weekly/SPY1213A130_D.csv'}
# data dates: <class 'pandas.tseries.index.DatetimeIndex'>
# [2012-01-05, ..., 2012-01-13]
# Length: 7, Freq: None, Timezone: None
# business day: 2012-01-12
# opt_strike:  130.0
# opt_price:  0.36
# ba_price:  128.84
# opt profit:  0.0
# I: selected option with expiry datetime.date(2012, 1, 13)
# D: round_func: <function nearest_higher at 0x47b9c80>
# I: rounding the strike from 129.57 to 130.0
# D: lower_strikes: [129.0, 128.0, 127.0, 126.0, 125.0, 124.0, 123.0, 122.0, 121.0]
# D: matching_strikes: [130.0]
# D: higher_strikes: [131.0, 132.0, 133.0, 134.0, 135.0, 136.0, 137.0]
# loading file: /home/mad/Options/CBOE/SPY/Weekly/SPY1213A134_D.csv
# fileinfo: {'load_func': <bound method type.load_func of <class '__main__.OptParserCBOE'>>, 'symbol': 'SPY', 'opt_type': 'C', 'exp_date': datetime.date(2012, 1, 13), 'strike': 134.0, 'data':                O     H     L     C     V    OI
# timestamp
# 2012-01-05  0.01  0.04  0.01  0.03    71    71
# 2012-01-06  0.02  0.03  0.02  0.02   638   651
# 2012-01-09  0.03  0.03  0.02  0.02   134   765
# 2012-01-10  0.02  0.03  0.02  0.02  4491  4966
# 2012-01-11  0.01  0.02  0.01  0.01   440  4927
# 2012-01-12  0.01  0.01  0.01  0.01    40  4967, 'file_path': '/home/mad/Options/CBOE/SPY/Weekly/SPY1213A134_D.csv'}
# data dates: <class 'pandas.tseries.index.DatetimeIndex'>
# [2012-01-05, ..., 2012-01-12]
# Length: 6, Freq: None, Timezone: None
# business day: 2012-01-12
# opt_strike:  134.0
# opt_price:  0.01
# ba_price:  128.84
# opt profit:  0.0
# I: selected option with expiry datetime.date(2012, 1, 13)
# D: round_func: <function nearest_lower at 0x47b9f50>
# I: rounding the strike from 129.57 to 129.0
# D: lower_strikes: [128.0, 127.0, 126.0, 125.0, 124.0, 123.0, 122.0, 121.0, 120.0]
# D: matching_strikes: [129.0]
# D: higher_strikes: [130.0, 131.0, 132.0, 133.0, 134.0, 135.0, 136.0, 137.0]
# loading file: /home/mad/Options/CBOE/SPY/Weekly/SPY1213M129_D.csv
# fileinfo: {'load_func': <bound method type.load_func of <class '__main__.OptParserCBOE'>>, 'symbol': 'SPY', 'opt_type': 'P', 'exp_date': datetime.date(2012, 1, 13), 'strike': 129.0, 'data':                O     H     L     C       V     OI
# timestamp
# 2012-01-05  2.70  2.83  1.65  1.75     576    436
# 2012-01-06  1.69  2.15  1.58  1.75    3927   3619
# 2012-01-09  1.57  1.88  1.33  1.41    3851   5145
# 2012-01-10  0.60  0.81  0.53  0.76   30519  12070
# 2012-01-11  0.81  0.96  0.45  0.48   55474  26235
# 2012-01-12  0.31  0.75  0.17  0.18  123496  45194
# 2012-01-13  0.55  1.30  0.01  0.02  122237  15345, 'file_path': '/home/mad/Options/CBOE/SPY/Weekly/SPY1213M129_D.csv'}
# data dates: <class 'pandas.tseries.index.DatetimeIndex'>
# [2012-01-05, ..., 2012-01-13]
# Length: 7, Freq: None, Timezone: None
# business day: 2012-01-12
# opt_strike:  129.0
# opt_price:  0.31
# ba_price:  128.84
# opt profit:  0.0
# I: selected option with expiry datetime.date(2012, 1, 13)
# D: round_func: <function nearest_lower at 0x47b9f50>
# I: rounding the strike from 129.57 to 129.0
# D: lower_strikes: [128.0, 127.0, 126.0, 125.0, 124.0, 123.0, 122.0, 121.0, 120.0]
# D: matching_strikes: [129.0]
# D: higher_strikes: [130.0, 131.0, 132.0, 133.0, 134.0, 135.0, 136.0, 137.0]
# loading file: /home/mad/Options/CBOE/SPY/Weekly/SPY1213M123_D.csv
# fileinfo: {'load_func': <bound method type.load_func of <class '__main__.OptParserCBOE'>>, 'symbol': 'SPY', 'opt_type': 'P', 'exp_date': datetime.date(2012, 1, 13), 'strike': 123.0, 'data':                O     H     L     C     V    OI
# timestamp
# 2012-01-05  0.36  0.44  0.16  0.20  4295  3438
# 2012-01-06  0.14  0.21  0.12  0.15  3474  4808
# 2012-01-09  0.08  0.13  0.05  0.06  7105  8020
# 2012-01-10  0.01  0.03  0.01  0.02  2609  7574
# 2012-01-11  0.03  0.03  0.01  0.01   470  7631
# 2012-01-12  0.01  0.02  0.01  0.01  1305  8107
# 2012-01-13  0.01  0.01  0.01  0.01    55  8107, 'file_path': '/home/mad/Options/CBOE/SPY/Weekly/SPY1213M123_D.csv'}
# data dates: <class 'pandas.tseries.index.DatetimeIndex'>
# [2012-01-05, ..., 2012-01-13]
# Length: 7, Freq: None, Timezone: None
# business day: 2012-01-12
# opt_strike:  123.0
# opt_price:  0.01
# ba_price:  128.84
# opt profit:  5.84
#
# res line: {'o3_price': 0.31, 'o1_strike': 130.0, 'o4_profit': -0.01, 'o2_price': 0.01, 'ba_close_price': 128.84, 'ba_on_close_date': Timestamp('2012-01-13 00:00:00'), 'profit': 0.49000000000000332, 'price': Decimal('129.56999999999999317878973670303821563720703125'), 'o4_price': 0.01, 'o3_profit': 0.15000000000000341, 'o3_strike': 129.0, 'o4_strike': 123.0, 'o1_profit': 0.35999999999999999, 'close_date': datetime.date(2012, 1, 13), 'o1_price': 0.35999999999999999, 'o2_strike': 134.0, 'o2_profit': -0.01}
#
# idx: 2012-01-19 00:00:00
#
# row: {'C': 131.46000000000001, 'Buy': True, 'Profit': 0, 'H': 131.56999999999999, 'L': 130.80000000000001, 'Decile': 0.020408163265306121, 'volat': 0.0058572949946750479, 'O': 131.22}
#
# next_day: {'C': 131.53999999999999, 'Buy': False, 'Profit': 0.0, 'H': 131.94999999999999, 'L': 130.91999999999999, 'Decile': 0.16326530612244897, 'volat': 0.007830317774061131, 'O': 131.24000000000001}
#
#
# I: selected option with expiry datetime.date(2012, 1, 27)
# D: round_func: <function nearest_higher at 0x47b9c80>
# I: rounding the strike from 131.24 to 132.0
# D: lower_strikes: [131.0, 130.0, 129.0, 128.0, 127.0, 126.0, 125.0, 124.0, 123.0]
# D: matching_strikes: [132.0]
# D: higher_strikes: [133.0, 134.0, 135.0, 136.0, 137.0, 138.0, 139.0, 140.0]
# loading file: /home/mad/Options/CBOE/SPY/Weekly/SPY1227A132_D.csv
# fileinfo: {'load_func': <bound method type.load_func of <class '__main__.OptParserCBOE'>>, 'symbol': 'SPY', 'opt_type': 'C', 'exp_date': datetime.date(2012, 1, 27), 'strike': 132.0, 'file_path': '/home/mad/Options/CBOE/SPY/Weekly/SPY1227A132_D.csv'}
# data dates: <class 'pandas.tseries.index.DatetimeIndex'>
# [2012-01-19, ..., 2012-01-27]
# Length: 7, Freq: None, Timezone: None
# business day: 2012-01-20
# opt_strike:  132.0
# opt_price:  0.78
# ba_price:  131.82
# opt profit:  0.0
# I: selected option with expiry datetime.date(2012, 1, 27)
# D: round_func: <function nearest_higher at 0x47b9c80>
# I: rounding the strike from 131.24 to 132.0
# D: lower_strikes: [131.0, 130.0, 129.0, 128.0, 127.0, 126.0, 125.0, 124.0, 123.0]
# D: matching_strikes: [132.0]
# D: higher_strikes: [133.0, 134.0, 135.0, 136.0, 137.0, 138.0, 139.0, 140.0]
# loading file: /home/mad/Options/CBOE/SPY/Weekly/SPY1227A136_D.csv
# fileinfo: {'load_func': <bound method type.load_func of <class '__main__.OptParserCBOE'>>, 'symbol': 'SPY', 'opt_type': 'C', 'exp_date': datetime.date(2012, 1, 27), 'strike': 136.0, 'file_path': '/home/mad/Options/CBOE/SPY/Weekly/SPY1227A136_D.csv'}
# data dates: <class 'pandas.tseries.index.DatetimeIndex'>
# [2012-01-19, ..., 2012-01-27]
# Length: 7, Freq: None, Timezone: None
# business day: 2012-01-20
# opt_strike:  136.0
# opt_price:  0.06
# ba_price:  131.82
# opt profit:  0.0
# I: selected option with expiry datetime.date(2012, 1, 27)
# D: round_func: <function nearest_lower at 0x47b9f50>
# I: rounding the strike from 131.24 to 131.0
# D: lower_strikes: [130.0, 129.0, 128.0, 127.0, 126.0, 125.0, 124.0, 123.0, 122.0]
# D: matching_strikes: [131.0]
# D: higher_strikes: [132.0, 133.0, 134.0, 135.0, 136.0, 137.0, 138.0, 139.0, 140.0]
# loading file: /home/mad/Options/CBOE/SPY/Weekly/SPY1227M131_D.csv
# fileinfo: {'load_func': <bound method type.load_func of <class '__main__.OptParserCBOE'>>, 'symbol': 'SPY', 'opt_type': 'P', 'exp_date': datetime.date(2012, 1, 27), 'strike': 131.0, 'file_path': '/home/mad/Options/CBOE/SPY/Weekly/SPY1227M131_D.csv'}
# data dates: <class 'pandas.tseries.index.DatetimeIndex'>
# [2012-01-19, ..., 2012-01-27]
# Length: 7, Freq: None, Timezone: None
# business day: 2012-01-20
# opt_strike:  131.0
# opt_price:  1.09
# ba_price:  131.82
# opt profit:  0.82
# I: selected option with expiry datetime.date(2012, 1, 27)
# D: round_func: <function nearest_lower at 0x47b9f50>
# I: rounding the strike from 131.24 to 131.0
# D: lower_strikes: [130.0, 129.0, 128.0, 127.0, 126.0, 125.0, 124.0, 123.0, 122.0]
# D: matching_strikes: [131.0]
# D: higher_strikes: [132.0, 133.0, 134.0, 135.0, 136.0, 137.0, 138.0, 139.0, 140.0]
# loading file: /home/mad/Options/CBOE/SPY/Weekly/SPY1227M125_D.csv
# fileinfo: {'load_func': <bound method type.load_func of <class '__main__.OptParserCBOE'>>, 'symbol': 'SPY', 'opt_type': 'P', 'exp_date': datetime.date(2012, 1, 27), 'strike': 125.0, 'file_path': '/home/mad/Options/CBOE/SPY/Weekly/SPY1227M125_D.csv'}
# data dates: <class 'pandas.tseries.index.DatetimeIndex'>
# [2012-01-19, ..., 2012-01-27]
# Length: 7, Freq: None, Timezone: None
# business day: 2012-01-20
# opt_strike:  125.0
# opt_price:  0.11
# ba_price:  131.82
# opt profit:  6.82
#
# res line: {'o3_price': 1.0900000000000001, 'o1_strike': 132.0, 'o4_profit': -0.11, 'o2_price': 0.059999999999999998, 'ba_close_price': 131.81999999999999, 'ba_on_close_date': Timestamp('2012-01-27 00:00:00'), 'profit': 1.7, 'price': Decimal('131.240000000000009094947017729282379150390625'), 'o4_price': 0.11, 'o3_profit': 1.0900000000000001, 'o3_strike': 131.0, 'o4_strike': 125.0, 'o1_profit': 0.78000000000000003, 'close_date': datetime.date(2012, 1, 27), 'o1_price': 0.78000000000000003, 'o2_strike': 136.0, 'o2_profit': -0.059999999999999998}
#
# idx: 2012-02-02 00:00:00
#
# row: {'C': 132.68000000000001, 'Buy': True, 'Profit': 0, 'H': 133.02000000000001, 'L': 132.21000000000001, 'Decile': 0.081632653061224483, 'volat': 0.0061049140789870534, 'O': 132.72999999999999}
#
# next_day: {'C': 134.53999999999999, 'Buy': False, 'Profit': 0.0, 'H': 134.62, 'L': 133.77000000000001, 'Decile': 0.10204081632653061, 'volat': 0.0063178236955551831, 'O': 134.0}
#
#
# I: selected option with expiry datetime.date(2012, 2, 10)
# D: lower_strikes: [133.0, 132.0, 131.0, 130.0, 129.0, 128.0, 127.0, 126.0, 125.0]
# D: matching_strikes: [134.0]
# D: higher_strikes: [135.0, 136.0, 137.0, 138.0, 139.0, 140.0, 141.0, 142.0, 143.0]
# loading file: /home/mad/Options/CBOE/SPY/Weekly/SPY1210B134_D.csv
# fileinfo: {'load_func': <bound method type.load_func of <class '__main__.OptParserCBOE'>>, 'symbol': 'SPY', 'opt_type': 'C', 'exp_date': datetime.date(2012, 2, 10), 'strike': 134.0, 'file_path': '/home/mad/Options/CBOE/SPY/Weekly/SPY1210B134_D.csv'}
# data dates: <class 'pandas.tseries.index.DatetimeIndex'>
# [2012-02-02, ..., 2012-02-10]
# Length: 7, Freq: None, Timezone: None
# business day: 2012-02-03
# opt_strike:  134.0
# opt_price:  0.97
# ba_price:  134.361
# opt profit:  0.361
# I: selected option with expiry datetime.date(2012, 2, 10)
# D: lower_strikes: [133.0, 132.0, 131.0, 130.0, 129.0, 128.0, 127.0, 126.0, 125.0]
# D: matching_strikes: [134.0]
# D: higher_strikes: [135.0, 136.0, 137.0, 138.0, 139.0, 140.0, 141.0, 142.0, 143.0]
# loading file: /home/mad/Options/CBOE/SPY/Weekly/SPY1210B138_D.csv
# fileinfo: {'load_func': <bound method type.load_func of <class '__main__.OptParserCBOE'>>, 'symbol': 'SPY', 'opt_type': 'C', 'exp_date': datetime.date(2012, 2, 10), 'strike': 138.0, 'file_path': '/home/mad/Options/CBOE/SPY/Weekly/SPY1210B138_D.csv'}
# data dates: <class 'pandas.tseries.index.DatetimeIndex'>
# [2012-02-02, ..., 2012-02-10]
# Length: 7, Freq: None, Timezone: None
# business day: 2012-02-03
# opt_strike:  138.0
# opt_price:  0.06
# ba_price:  134.361
# opt profit:  0.0
# I: selected option with expiry datetime.date(2012, 2, 10)
# D: lower_strikes: [133.0, 132.0, 131.0, 130.0, 129.0, 128.0, 127.0, 126.0, 125.0]
# D: matching_strikes: [134.0]
# D: higher_strikes: [135.0, 136.0, 137.0, 138.0, 139.0, 140.0, 141.0, 142.0, 143.0]
# loading file: /home/mad/Options/CBOE/SPY/Weekly/SPY1210N134_D.csv
# fileinfo: {'load_func': <bound method type.load_func of <class '__main__.OptParserCBOE'>>, 'symbol': 'SPY', 'opt_type': 'P', 'exp_date': datetime.date(2012, 2, 10), 'strike': 134.0, 'file_path': '/home/mad/Options/CBOE/SPY/Weekly/SPY1210N134_D.csv'}
# data dates: <class 'pandas.tseries.index.DatetimeIndex'>
# [2012-02-02, ..., 2012-02-10]
# Length: 7, Freq: None, Timezone: None
# business day: 2012-02-03
# opt_strike:  134.0
# opt_price:  1.0
# ba_price:  134.361
# opt profit:  0.361
# I: selected option with expiry datetime.date(2012, 2, 10)
# D: lower_strikes: [133.0, 132.0, 131.0, 130.0, 129.0, 128.0, 127.0, 126.0, 125.0]
# D: matching_strikes: [134.0]
# D: higher_strikes: [135.0, 136.0, 137.0, 138.0, 139.0, 140.0, 141.0, 142.0, 143.0]
# loading file: /home/mad/Options/CBOE/SPY/Weekly/SPY1210N128_D.csv
# fileinfo: {'load_func': <bound method type.load_func of <class '__main__.OptParserCBOE'>>, 'symbol': 'SPY', 'opt_type': 'P', 'exp_date': datetime.date(2012, 2, 10), 'strike': 128.0, 'file_path': '/home/mad/Options/CBOE/SPY/Weekly/SPY1210N128_D.csv'}
# data dates: <class 'pandas.tseries.index.DatetimeIndex'>
# [2012-02-02, ..., 2012-02-10]
# Length: 7, Freq: None, Timezone: None
# business day: 2012-02-03
# opt_strike:  128.0
# opt_price:  0.08
# ba_price:  134.361
# opt profit:  6.361
#
# res line: {'o3_price': 1.0, 'o1_strike': 134.0, 'o4_profit': -0.080000000000000002, 'o2_price': 0.059999999999999998, 'ba_close_price': 134.36099999999999, 'ba_on_close_date': Timestamp('2012-02-10 00:00:00'), 'profit': 1.4690000000000099, 'price': Decimal('134'), 'o4_price': 0.080000000000000002, 'o3_profit': 1.0, 'o3_strike': 134.0, 'o4_strike': 128.0, 'o1_profit': 0.60900000000000998, 'close_date': datetime.date(2012, 2, 10), 'o1_price': 0.96999999999999997, 'o2_strike': 138.0, 'o2_profit': -0.059999999999999998}
#
# idx: 2012-02-06 00:00:00
#
# row: {'C': 134.44999999999999, 'Buy': True, 'Profit': 0, 'H': 134.51339999999999, 'L': 133.83000000000001, 'Decile': 0.0, 'volat': 0.0050829304574189485, 'O': 133.97999999999999}
#
# next_day: {'C': 134.78999999999999, 'Buy': False, 'Profit': 0.0, 'H': 135.02000000000001, 'L': 133.63999999999999, 'Decile': 0.44897959183673469, 'volat': 0.010238148230581081, 'O': 134.16999999999999}
#
#
# I: selected option with expiry datetime.date(2012, 2, 10)
# D: round_func: <function nearest_higher at 0x47b9c80>
# I: rounding the strike from 134.17 to 135.0
# D: lower_strikes: [134.0, 133.0, 132.0, 131.0, 130.0, 129.0, 128.0, 127.0, 126.0]
# D: matching_strikes: [135.0]
# D: higher_strikes: [136.0, 137.0, 138.0, 139.0, 140.0, 141.0, 142.0, 143.0, 144.0]
# loading file: /home/mad/Options/CBOE/SPY/Weekly/SPY1210B135_D.csv
# fileinfo: {'load_func': <bound method type.load_func of <class '__main__.OptParserCBOE'>>, 'symbol': 'SPY', 'opt_type': 'C', 'exp_date': datetime.date(2012, 2, 10), 'strike': 135.0, 'file_path': '/home/mad/Options/CBOE/SPY/Weekly/SPY1210B135_D.csv'}
# data dates: <class 'pandas.tseries.index.DatetimeIndex'>
# [2012-02-02, ..., 2012-02-10]
# Length: 7, Freq: None, Timezone: None
# business day: 2012-02-07
# opt_strike:  135.0
# opt_price:  0.44
# ba_price:  134.361
# opt profit:  0.0
# I: selected option with expiry datetime.date(2012, 2, 10)
# D: round_func: <function nearest_higher at 0x47b9c80>
# I: rounding the strike from 134.17 to 135.0
# D: lower_strikes: [134.0, 133.0, 132.0, 131.0, 130.0, 129.0, 128.0, 127.0, 126.0]
# D: matching_strikes: [135.0]
# D: higher_strikes: [136.0, 137.0, 138.0, 139.0, 140.0, 141.0, 142.0, 143.0, 144.0]
# loading file: /home/mad/Options/CBOE/SPY/Weekly/SPY1210B139_D.csv
# fileinfo: {'load_func': <bound method type.load_func of <class '__main__.OptParserCBOE'>>, 'symbol': 'SPY', 'opt_type': 'C', 'exp_date': datetime.date(2012, 2, 10), 'strike': 139.0, 'file_path': '/home/mad/Options/CBOE/SPY/Weekly/SPY1210B139_D.csv'}
# data dates: <class 'pandas.tseries.index.DatetimeIndex'>
# [2012-02-02, ..., 2012-02-10]
# Length: 7, Freq: None, Timezone: None
# business day: 2012-02-07
# opt_strike:  139.0
# opt_price:  0.02
# ba_price:  134.361
# opt profit:  0.0
# I: selected option with expiry datetime.date(2012, 2, 10)
# D: round_func: <function nearest_lower at 0x47b9f50>
# I: rounding the strike from 134.17 to 134.0
# D: lower_strikes: [133.0, 132.0, 131.0, 130.0, 129.0, 128.0, 127.0, 126.0, 125.0]
# D: matching_strikes: [134.0]
# D: higher_strikes: [135.0, 136.0, 137.0, 138.0, 139.0, 140.0, 141.0, 142.0, 143.0]
# loading file: /home/mad/Options/CBOE/SPY/Weekly/SPY1210N134_D.csv
# fileinfo: {'load_func': <bound method type.load_func of <class '__main__.OptParserCBOE'>>, 'symbol': 'SPY', 'opt_type': 'P', 'exp_date': datetime.date(2012, 2, 10), 'strike': 134.0, 'data':                O     H     L     C       V      OI
# timestamp
# 2012-02-02  1.90  2.21  1.69  1.81    1559     552
# 2012-02-03  1.00  1.14  0.77  0.87   88412   63008
# 2012-02-06  1.03  1.04  0.66  0.70   34463   75888
# 2012-02-07  0.79  1.03  0.40  0.42   51687   91400
# 2012-02-08  0.41  0.60  0.27  0.30   73722  104877
# 2012-02-09  0.21  0.39  0.07  0.09   56616  105303
# 2012-02-10  0.34  0.44  0.01  0.01  151306   83157, 'file_path': '/home/mad/Options/CBOE/SPY/Weekly/SPY1210N134_D.csv'}
# data dates: <class 'pandas.tseries.index.DatetimeIndex'>
# [2012-02-02, ..., 2012-02-10]
# Length: 7, Freq: None, Timezone: None
# business day: 2012-02-07
# opt_strike:  134.0
# opt_price:  0.79
# ba_price:  134.361
# opt profit:  0.361
# I: selected option with expiry datetime.date(2012, 2, 10)
# D: round_func: <function nearest_lower at 0x47b9f50>
# I: rounding the strike from 134.17 to 134.0
# D: lower_strikes: [133.0, 132.0, 131.0, 130.0, 129.0, 128.0, 127.0, 126.0, 125.0]
# D: matching_strikes: [134.0]
# D: higher_strikes: [135.0, 136.0, 137.0, 138.0, 139.0, 140.0, 141.0, 142.0, 143.0]
# loading file: /home/mad/Options/CBOE/SPY/Weekly/SPY1210N128_D.csv
# fileinfo: {'load_func': <bound method type.load_func of <class '__main__.OptParserCBOE'>>, 'symbol': 'SPY', 'opt_type': 'P', 'exp_date': datetime.date(2012, 2, 10), 'strike': 128.0, 'data':                O     H     L     C     V     OI
# timestamp
# 2012-02-02  0.15  0.21  0.14  0.16  4237   3514
# 2012-02-03  0.08  0.12  0.05  0.08  9302  11293
# 2012-02-06  0.07  0.07  0.05  0.05  3712  12884
# 2012-02-07  0.04  0.05  0.02  0.03  1066  13198
# 2012-02-08  0.02  0.03  0.01  0.02  8880  12379
# 2012-02-09  0.01  0.02  0.01  0.01  1998  12482
# 2012-02-10  0.01  0.01  0.01  0.01   131  12482, 'file_path': '/home/mad/Options/CBOE/SPY/Weekly/SPY1210N128_D.csv'}
# data dates: <class 'pandas.tseries.index.DatetimeIndex'>
# [2012-02-02, ..., 2012-02-10]
# Length: 7, Freq: None, Timezone: None
# business day: 2012-02-07
# opt_strike:  128.0
# opt_price:  0.04
# ba_price:  134.361
# opt profit:  6.361
#
# res line: {'o3_price': 0.79000000000000004, 'o1_strike': 135.0, 'o4_profit': -0.040000000000000001, 'o2_price': 0.02, 'ba_close_price': 134.36099999999999, 'ba_on_close_date': Timestamp('2012-02-10 00:00:00'), 'profit': 1.1699999999999999, 'price': Decimal('134.169999999999987494447850622236728668212890625'), 'o4_price': 0.040000000000000001, 'o3_profit': 0.79000000000000004, 'o3_strike': 134.0, 'o4_strike': 128.0, 'o1_profit': 0.44, 'close_date': datetime.date(2012, 2, 10), 'o1_price': 0.44, 'o2_strike': 139.0, 'o2_profit': -0.02}
#
# idx: 2012-02-10 00:00:00
#
# row: {'C': 134.36099999999999, 'Buy': True, 'Profit': 0, 'H': 134.47, 'L': 133.84, 'Decile': 0.0, 'volat': 0.0046888606068724963, 'O': 134.16}
#
# next_day: {'C': 135.36000000000001, 'Buy': True, 'Profit': 0.0, 'H': 135.52000000000001, 'L': 134.74000000000001, 'Decile': 0.061224489795918366, 'volat': 0.0057624113475177379, 'O': 135.31999999999999}
#
#
# I: selected option with expiry datetime.date(2012, 2, 17)
# D: round_func: <function nearest_higher at 0x47b9c80>
# I: rounding the strike from 135.32 to 136.0
# D: lower_strikes: [135.0, 134.0, 133.0, 132.0, 131.0, 130.0, 129.0, 128.0, 127.0]
# D: matching_strikes: [136.0]
# D: higher_strikes: [137.0, 138.0, 139.0, 140.0, 141.0, 142.0, 143.0, 144.0, 145.0]
# loading file: /home/mad/Options/CBOE/SPY/Monthly/SPY1218B136_D.csv
# fileinfo: {'load_func': <bound method type.load_func of <class '__main__.OptParserCBOE'>>, 'symbol': 'SPY', 'opt_type': 'C', 'exp_date': datetime.date(2012, 2, 17), 'strike': 136.0, 'file_path': '/home/mad/Options/CBOE/SPY/Monthly/SPY1218B136_D.csv'}
# data dates: <class 'pandas.tseries.index.DatetimeIndex'>
# [2011-10-24, ..., 2012-02-17]
# Length: 74, Freq: None, Timezone: None
# weekend (Saturday): 2012-02-11
# weekend (Sunday): 2012-02-12
# business day: 2012-02-13
# opt_strike:  136.0
# opt_price:  0.68
# ba_price:  136.41
# opt profit:  0.41
# I: selected option with expiry datetime.date(2012, 2, 17)
# D: round_func: <function nearest_higher at 0x47b9c80>
# I: rounding the strike from 135.32 to 136.0
# D: lower_strikes: [135.0, 134.0, 133.0, 132.0, 131.0, 130.0, 129.0, 128.0, 127.0]
# D: matching_strikes: [136.0]
# D: higher_strikes: [137.0, 138.0, 139.0, 140.0, 141.0, 142.0, 143.0, 144.0, 145.0]
# loading file: /home/mad/Options/CBOE/SPY/Monthly/SPY1218B140_D.csv
# fileinfo: {'load_func': <bound method type.load_func of <class '__main__.OptParserCBOE'>>, 'symbol': 'SPY', 'opt_type': 'C', 'exp_date': datetime.date(2012, 2, 17), 'strike': 140.0, 'file_path': '/home/mad/Options/CBOE/SPY/Monthly/SPY1218B140_D.csv'}
# data dates: <class 'pandas.tseries.index.DatetimeIndex'>
# [2011-10-24, ..., 2012-02-17]
# Length: 75, Freq: None, Timezone: None
# weekend (Saturday): 2012-02-11
# weekend (Sunday): 2012-02-12
# business day: 2012-02-13
# opt_strike:  140.0
# opt_price:  0.01
# ba_price:  136.41
# opt profit:  0.0
# I: selected option with expiry datetime.date(2012, 2, 17)
# D: round_func: <function nearest_lower at 0x47b9f50>
# I: rounding the strike from 135.32 to 135.0
# D: lower_strikes: [134.0, 133.0, 132.0, 131.0, 130.0, 129.0, 128.0, 127.0, 126.0]
# D: matching_strikes: [135.0]
# D: higher_strikes: [136.0, 137.0, 138.0, 139.0, 140.0, 141.0, 142.0, 143.0, 144.0]
# loading file: /home/mad/Options/CBOE/SPY/Monthly/SPY1218N135_D.csv
# fileinfo: {'load_func': <bound method type.load_func of <class '__main__.OptParserCBOE'>>, 'symbol': 'SPY', 'opt_type': 'P', 'exp_date': datetime.date(2012, 2, 17), 'strike': 135.0, 'file_path': '/home/mad/Options/CBOE/SPY/Monthly/SPY1218N135_D.csv'}
# data dates: <class 'pandas.tseries.index.DatetimeIndex'>
# [2011-10-24, ..., 2012-02-17]
# Length: 71, Freq: None, Timezone: None
# weekend (Saturday): 2012-02-11
# weekend (Sunday): 2012-02-12
# business day: 2012-02-13
# opt_strike:  135.0
# opt_price:  0.86
# ba_price:  136.41
# opt profit:  1.41
# I: selected option with expiry datetime.date(2012, 2, 17)
# D: round_func: <function nearest_lower at 0x47b9f50>
# I: rounding the strike from 135.32 to 135.0
# D: lower_strikes: [134.0, 133.0, 132.0, 131.0, 130.0, 129.0, 128.0, 127.0, 126.0]
# D: matching_strikes: [135.0]
# D: higher_strikes: [136.0, 137.0, 138.0, 139.0, 140.0, 141.0, 142.0, 143.0, 144.0]
# loading file: /home/mad/Options/CBOE/SPY/Monthly/SPY1218N129_D.csv
# fileinfo: {'load_func': <bound method type.load_func of <class '__main__.OptParserCBOE'>>, 'symbol': 'SPY', 'opt_type': 'P', 'exp_date': datetime.date(2012, 2, 17), 'strike': 129.0, 'file_path': '/home/mad/Options/CBOE/SPY/Monthly/SPY1218N129_D.csv'}
# data dates: <class 'pandas.tseries.index.DatetimeIndex'>
# [2011-10-25, ..., 2012-02-17]
# Length: 79, Freq: None, Timezone: None
# weekend (Saturday): 2012-02-11
# weekend (Sunday): 2012-02-12
# business day: 2012-02-13
# opt_strike:  129.0
# opt_price:  0.12
# ba_price:  136.41
# opt profit:  7.41
#
# res line: {'o3_price': 0.85999999999999999, 'o1_strike': 136.0, 'o4_profit': -0.12, 'o2_price': 0.01, 'ba_close_price': 136.41, 'ba_on_close_date': Timestamp('2012-02-17 00:00:00'), 'profit': 1.0000000000000036, 'price': Decimal('135.31999999999999317878973670303821563720703125'), 'o4_price': 0.12, 'o3_profit': 0.85999999999999999, 'o3_strike': 135.0, 'o4_strike': 129.0, 'o1_profit': 0.27000000000000346, 'close_date': datetime.date(2012, 2, 17), 'o1_price': 0.68000000000000005, 'o2_strike': 140.0, 'o2_profit': -0.01}
#
# idx: 2012-02-13 00:00:00
#
# row: {'C': 135.36000000000001, 'Buy': True, 'Profit': 0, 'H': 135.52000000000001, 'L': 134.74000000000001, 'Decile': 0.061224489795918366, 'volat': 0.0057624113475177379, 'O': 135.31999999999999}
#
# next_day: {'C': 135.19, 'Buy': False, 'Profit': 0.0, 'H': 135.27000000000001, 'L': 134.25, 'Decile': 0.32653061224489793, 'volat': 0.0075449367556772711, 'O': 135.0}
#
#
# I: selected option with expiry datetime.date(2012, 2, 17)
# D: lower_strikes: [134.0, 133.0, 132.0, 131.0, 130.0, 129.0, 128.0, 127.0, 126.0]
# D: matching_strikes: [135.0]
# D: higher_strikes: [136.0, 137.0, 138.0, 139.0, 140.0, 141.0, 142.0, 143.0, 144.0]
# loading file: /home/mad/Options/CBOE/SPY/Monthly/SPY1218B135_D.csv
# fileinfo: {'load_func': <bound method type.load_func of <class '__main__.OptParserCBOE'>>, 'symbol': 'SPY', 'opt_type': 'C', 'exp_date': datetime.date(2012, 2, 17), 'strike': 135.0, 'file_path': '/home/mad/Options/CBOE/SPY/Monthly/SPY1218B135_D.csv'}
# data dates: <class 'pandas.tseries.index.DatetimeIndex'>
# [2011-10-24, ..., 2012-02-17]
# Length: 81, Freq: None, Timezone: None
# business day: 2012-02-14
# opt_strike:  135.0
# opt_price:  0.85
# ba_price:  136.41
# opt profit:  1.41
# I: selected option with expiry datetime.date(2012, 2, 17)
# D: lower_strikes: [134.0, 133.0, 132.0, 131.0, 130.0, 129.0, 128.0, 127.0, 126.0]
# D: matching_strikes: [135.0]
# D: higher_strikes: [136.0, 137.0, 138.0, 139.0, 140.0, 141.0, 142.0, 143.0, 144.0]
# loading file: /home/mad/Options/CBOE/SPY/Monthly/SPY1218B139_D.csv
# fileinfo: {'load_func': <bound method type.load_func of <class '__main__.OptParserCBOE'>>, 'symbol': 'SPY', 'opt_type': 'C', 'exp_date': datetime.date(2012, 2, 17), 'strike': 139.0, 'file_path': '/home/mad/Options/CBOE/SPY/Monthly/SPY1218B139_D.csv'}
# data dates: <class 'pandas.tseries.index.DatetimeIndex'>
# [2011-10-24, ..., 2012-02-17]
# Length: 76, Freq: None, Timezone: None
# business day: 2012-02-14
# opt_strike:  139.0
# opt_price:  0.01
# ba_price:  136.41
# opt profit:  0.0
# I: selected option with expiry datetime.date(2012, 2, 17)
# D: lower_strikes: [134.0, 133.0, 132.0, 131.0, 130.0, 129.0, 128.0, 127.0, 126.0]
# D: matching_strikes: [135.0]
# D: higher_strikes: [136.0, 137.0, 138.0, 139.0, 140.0, 141.0, 142.0, 143.0, 144.0]
# loading file: /home/mad/Options/CBOE/SPY/Monthly/SPY1218N135_D.csv
# fileinfo: {'load_func': <bound method type.load_func of <class '__main__.OptParserCBOE'>>, 'symbol': 'SPY', 'opt_type': 'P', 'exp_date': datetime.date(2012, 2, 17), 'strike': 135.0, 'data':                 O      H      L      C       V      OI
# timestamp
# 2011-10-24  13.01  13.01  13.01  13.01       5       0
# 2011-10-28  10.02  10.02  10.02  10.02       4       5
# 2011-10-31  11.07  11.99  11.05  11.99     114       9
# 2011-11-01  15.62  15.66  15.62  15.66      15     107
# 2011-11-03  12.95  12.95  12.95  12.95       1     107
# 2011-11-04  13.12  13.35  12.69  12.69      41     107
# 2011-11-07  13.00  13.20  12.09  12.09      12     143
# 2011-11-09  12.99  13.36  12.99  13.36       7     144
# 2011-11-11  11.55  11.74  11.55  11.74      17     151
# 2011-11-14  12.15  12.71  12.15  12.44      33     166
# 2011-11-15  12.66  12.66  11.84  11.84      41     166
# 2011-11-16  11.90  13.33  11.90  13.33      38     191
# 2011-11-17  15.02  15.02  15.02  15.02       1     219
# 2011-11-18  14.95  15.01  14.95  15.01      12     218
# 2011-11-21  17.16  17.70  16.60  16.92     394     224
# 2011-11-22  17.02  17.02  16.89  16.89      36     596
# 2011-11-23  18.92  18.92  18.92  18.92       1     596
# 2011-11-28  16.53  16.70  16.42  16.70      91     595
# 2011-11-29  15.92  16.04  15.92  16.02      86     610
# 2011-11-30  13.47  13.66  12.09  12.09     475     591
# 2011-12-01  12.27  12.32  11.73  12.32     118     941
# 2011-12-02  11.34  12.03  11.00  11.73     137     848
# 2011-12-05  10.62  11.44  10.60  11.44      90     936
# 2011-12-06  11.15  11.32  10.53  10.75     204    1014
# 2011-12-07  12.00  12.00  11.00  11.00      40    1179
# 2011-12-08  11.60  13.17  11.60  13.17      60    1215
# 2011-12-09  11.79  11.79  11.79  11.79       9    1222
# 2011-12-12  12.66  12.66  12.58  12.58       3    1222
# 2011-12-13  11.25  11.95  11.25  11.95      11    1222
# 2011-12-14  14.14  14.58  14.14  14.45      13    1223
# ...           ...    ...    ...    ...     ...     ...
# 2012-01-06   7.85   8.19   7.43   7.71     129    1239
# 2012-01-09   7.69   7.80   7.44   7.44      33    1253
# 2012-01-10   6.29   6.62   6.20   6.55     890    1409
# 2012-01-11   6.98   6.98   6.35   6.40     175    1493
# 2012-01-12   6.29   6.92   6.08   6.14     547    1685
# 2012-01-13   6.80   7.65   6.49   6.49     448    1818
# 2012-01-17   5.68   6.40   5.43   6.20    1125    2741
# ...
# data dates: <class 'pandas.tseries.index.DatetimeIndex'>
# [2014-10-31, ..., 2014-12-12]
# Length: 22, Freq: None, Timezone: None
# weekend (Saturday): 2014-12-06
# weekend (Sunday): 2014-12-07
# business day: 2014-12-08
# opt_strike:  207.0
# opt_price:  0.68
# ba_price:  200.89
# opt profit:  0.0
# I: selected option with expiry datetime.date(2014, 12, 12)
# D: round_func: <function nearest_lower at 0x47b9f50>
# I: rounding the strike from 207.52 to 207.0
# D: lower_strikes: [206.0, 205.0, 204.0, 203.0, 202.0, 201.0, 200.0, 199.0, 198.0]
# D: matching_strikes: [207.0]
# D: higher_strikes: [208.0, 209.0, 210.0, 211.0, 212.0, 213.0, 214.0, 215.0, 220.0]
# loading file: /home/mad/Options/CBOE/SPY/Weekly/SPY1412X201_D.csv
# fileinfo: {'load_func': <bound method type.load_func of <class '__main__.OptParserCBOE'>>, 'symbol': 'SPY', 'opt_type': 'P', 'exp_date': datetime.date(2014, 12, 12), 'strike': 201.0, 'file_path': '/home/mad/Options/CBOE/SPY/Weekly/SPY1412X201_D.csv'}
# data dates: <class 'pandas.tseries.index.DatetimeIndex'>
# [2014-10-30, ..., 2014-12-12]
# Length: 31, Freq: None, Timezone: None
# weekend (Saturday): 2014-12-06
# weekend (Sunday): 2014-12-07
# business day: 2014-12-08
# opt_strike:  201.0
# opt_price:  0.09
# ba_price:  200.89
# opt profit:  0.0
#
# res line: {'o3_price': 0.68000000000000005, 'o1_strike': 208.0, 'o4_profit': 0.020000000000013646, 'o2_price': 0.01, 'ba_close_price': 200.88999999999999, 'ba_on_close_date': Timestamp('2014-12-12 00:00:00'), 'profit': -4.7300000000000004, 'price': Decimal('207.520000000000010231815394945442676544189453125'), 'o4_price': 0.089999999999999997, 'o3_profit': -5.4300000000000139, 'o3_strike': 207.0, 'o4_strike': 201.0, 'o1_profit': 0.68999999999999995, 'close_date': datetime.date(2014, 12, 12), 'o1_price': 0.68999999999999995, 'o2_strike': 212.0, 'o2_profit': -0.01}
#
# idx: 2014-12-23 00:00:00
#
# row: {'C': 207.75, 'Buy': True, 'Profit': 0, 'H': 208.22999999999999, 'L': 207.3991, 'Decile': 0.081632653061224483, 'volat': 0.0039995186522261642, 'O': 208.16999999999999}
#
# next_day: {'C': 207.77000000000001, 'Buy': True, 'Profit': 0.0, 'H': 208.34, 'L': 207.72, 'Decile': 0.020408163265306121, 'volat': 0.0029840689223660996, 'O': 208.02000000000001}
#
#
# I: selected option with expiry datetime.date(2014, 12, 26)
# D: round_func: <function nearest_higher at 0x47b9c80>
# I: rounding the strike from 208.02 to 209.0
# D: lower_strikes: [208.0, 207.0, 206.0, 205.0, 204.0, 203.0, 202.0, 201.0, 200.0]
# D: matching_strikes: [209.0]
# D: higher_strikes: [210.0, 211.0, 212.0, 213.0, 214.0, 215.0, 216.0, 217.0, 218.0]
# loading file: /home/mad/Options/CBOE/SPY/Weekly/SPY1426L209_D.csv
# fileinfo: {'load_func': <bound method type.load_func of <class '__main__.OptParserCBOE'>>, 'symbol': 'SPY', 'opt_type': 'C', 'exp_date': datetime.date(2014, 12, 26), 'strike': 209.0, 'file_path': '/home/mad/Options/CBOE/SPY/Weekly/SPY1426L209_D.csv'}
# data dates: <class 'pandas.tseries.index.DatetimeIndex'>
# [2014-11-07, ..., 2014-12-26]
# Length: 32, Freq: None, Timezone: None
# business day: 2014-12-24
# opt_strike:  209.0
# opt_price:  0.11
# ba_price:  208.44
# opt profit:  0.0
# I: selected option with expiry datetime.date(2014, 12, 26)
# D: round_func: <function nearest_higher at 0x47b9c80>
# I: rounding the strike from 208.02 to 209.0
# D: lower_strikes: [208.0, 207.0, 206.0, 205.0, 204.0, 203.0, 202.0, 201.0, 200.0]
# D: matching_strikes: [209.0]
# D: higher_strikes: [210.0, 211.0, 212.0, 213.0, 214.0, 215.0, 216.0, 217.0, 218.0]
# loading file: /home/mad/Options/CBOE/SPY/Weekly/SPY1426L213_D.csv
# fileinfo: {'load_func': <bound method type.load_func of <class '__main__.OptParserCBOE'>>, 'symbol': 'SPY', 'opt_type': 'C', 'exp_date': datetime.date(2014, 12, 26), 'strike': 213.0, 'file_path': '/home/mad/Options/CBOE/SPY/Weekly/SPY1426L213_D.csv'}
# data dates: <class 'pandas.tseries.index.DatetimeIndex'>
# [2014-11-28, ..., 2014-12-23]
# Length: 18, Freq: None, Timezone: None
# business day: 2014-12-24
# NoData at Timestamp('2014-12-23 00:00:00'): NoData('No option data from the the buy date', (<type 'exceptions.IndexError'>, IndexError('index 0 is out of bounds for axis 0 with size 0',), <traceback object at 0x5a365a8>), datetime.date(2014, 12, 24), <class 'pandas.tseries.index.DatetimeIndex'>
# [2014-11-28, ..., 2014-12-23]
# Length: 18, Freq: None, Timezone: None,                O     H     L     C     V    OI
# timestamp
# 2014-11-28  0.26  0.32  0.25  0.30   201   201
# 2014-12-01  0.24  0.24  0.17  0.17   183   380
# 2014-12-02  0.19  0.19  0.17  0.19  1111  1304
# 2014-12-03  0.20  0.22  0.19  0.22   245  1399
# 2014-12-04  0.15  0.18  0.15  0.17    25  1399
# 2014-12-05  0.15  0.15  0.15  0.15     6  1402
# 2014-12-08  0.11  0.11  0.08  0.08    15  1414
# 2014-12-09  0.09  0.09  0.06  0.07   138  1329
# 2014-12-10  0.05  0.05  0.03  0.04   219  1361
# 2014-12-11  0.07  0.07  0.05  0.05     3  1361
# 2014-12-12  0.04  0.04  0.03  0.03    29  1337
# 2014-12-15  0.02  0.02  0.01  0.01     8  1335
# 2014-12-16  0.03  0.10  0.03  0.04     5  1334
# 2014-12-17  0.03  0.03  0.03  0.03     5  1288
# 2014-12-18  0.04  0.04  0.03  0.04   110  1298
# 2014-12-19  0.04  0.07  0.03  0.06   604  1421
# 2014-12-22  0.03  0.03  0.02  0.02   280  1630
# 2014-12-23  0.01  0.01  0.01  0.01    26  1637)
#
# idx: 2014-12-24 00:00:00
#
# row: {'C': 207.77000000000001, 'Buy': True, 'Profit': 0, 'H': 208.34, 'L': 207.72, 'Decile': 0.020408163265306121, 'volat': 0.0029840689223660996, 'O': 208.02000000000001}
#
# next_day: {'C': 208.44, 'Buy': True, 'Profit': 0.0, 'H': 208.84999999999999, 'L': 208.25, 'Decile': 0.020408163265306121, 'volat': 0.0028785261945883434, 'O': 208.31}
#
#
# I: selected option with expiry datetime.date(2014, 12, 26)
# D: round_func: <function nearest_higher at 0x47b9c80>
# I: rounding the strike from 208.31 to 209.0
# D: lower_strikes: [208.0, 207.0, 206.0, 205.0, 204.0, 203.0, 202.0, 201.0, 200.0]
# D: matching_strikes: [209.0]
# D: higher_strikes: [210.0, 211.0, 212.0, 213.0, 214.0, 215.0, 216.0, 217.0, 218.0]
# loading file: /home/mad/Options/CBOE/SPY/Weekly/SPY1426L209_D.csv
# fileinfo: {'load_func': <bound method type.load_func of <class '__main__.OptParserCBOE'>>, 'symbol': 'SPY', 'opt_type': 'C', 'exp_date': datetime.date(2014, 12, 26), 'strike': 209.0, 'data':                O     H     L     C      V     OI
# timestamp
# 2014-11-07  0.95  0.95  0.95  0.95     10     10
# 2014-11-10  0.78  0.85  0.78  0.85     23      0
# 2014-11-12  0.81  0.91  0.81  0.81    114    136
# 2014-11-14  0.82  0.82  0.77  0.80     24    150
# 2014-11-17  0.78  0.78  0.75  0.75     11    161
# 2014-11-18  0.89  1.13  0.89  1.13      7    163
# 2014-11-19  0.83  0.83  0.83  0.83      3    166
# 2014-11-20  0.90  0.90  0.89  0.90     43    199
# 2014-11-21  1.56  1.56  1.12  1.13     13    205
# 2014-11-24  1.15  1.22  1.14  1.22     22    211
# 2014-11-25  1.35  1.39  1.13  1.18    279    375
# 2014-11-26  1.15  1.18  1.10  1.18    144    460
# 2014-11-28  1.21  1.37  1.20  1.24   1357   1730
# 2014-12-01  0.99  0.99  0.74  0.74   2228   3256
# 2014-12-02  0.79  1.05  0.79  1.00   1274   3426
# 2014-12-03  1.13  1.28  1.09  1.18    897   3980
# 2014-12-04  1.05  1.15  0.81  1.04   1264   4249
# 2014-12-05  1.00  1.17  0.92  1.02   1608   4512
# 2014-12-08  0.82  0.95  0.55  0.59    270   4597
# 2014-12-09  0.33  0.62  0.33  0.62    619   4822
# 2014-12-10  0.42  0.42  0.27  0.29    750   4802
# 2014-12-11  0.29  0.54  0.29  0.37   1181   5488
# 2014-12-12  0.22  0.26  0.12  0.12   1026   5506
# 2014-12-15  0.08  0.08  0.04  0.04     81   5452
# 2014-12-16  0.03  0.07  0.03  0.07      6   5455
# 2014-12-17  0.06  0.26  0.05  0.06     32   5442
# 2014-12-18  0.12  0.31  0.10  0.31   3392   6046
# 2014-12-19  0.40  0.46  0.22  0.29  13158  13308
# 2014-12-22  0.22  0.25  0.14  0.17   8974  15442
# 2014-12-23  0.31  0.31  0.10  0.13  10073  18042
# 2014-12-24  0.11  0.11  0.05  0.05   4966  17114
# 2014-12-26  0.05  0.12  0.01  0.01  17286  16047, 'file_path': '/home/mad/Options/CBOE/SPY/Weekly/SPY1426L209_D.csv'}
# data dates: <class 'pandas.tseries.index.DatetimeIndex'>
# [2014-11-07, ..., 2014-12-26]
# Length: 32, Freq: None, Timezone: None
# holiday from list: 2014-12-25
# business day: 2014-12-26
# opt_strike:  209.0
# opt_price:  0.05
# ba_price:  208.44
# opt profit:  0.0
# I: selected option with expiry datetime.date(2014, 12, 26)
# D: round_func: <function nearest_higher at 0x47b9c80>
# I: rounding the strike from 208.31 to 209.0
# D: lower_strikes: [208.0, 207.0, 206.0, 205.0, 204.0, 203.0, 202.0, 201.0, 200.0]
# D: matching_strikes: [209.0]
# D: higher_strikes: [210.0, 211.0, 212.0, 213.0, 214.0, 215.0, 216.0, 217.0, 218.0]
# loading file: /home/mad/Options/CBOE/SPY/Weekly/SPY1426L213_D.csv
# fileinfo: {'load_func': <bound method type.load_func of <class '__main__.OptParserCBOE'>>, 'symbol': 'SPY', 'opt_type': 'C', 'exp_date': datetime.date(2014, 12, 26), 'strike': 213.0, 'data':                O     H     L     C     V    OI
# timestamp
# 2014-11-28  0.26  0.32  0.25  0.30   201   201
# 2014-12-01  0.24  0.24  0.17  0.17   183   380
# 2014-12-02  0.19  0.19  0.17  0.19  1111  1304
# 2014-12-03  0.20  0.22  0.19  0.22   245  1399
# 2014-12-04  0.15  0.18  0.15  0.17    25  1399
# 2014-12-05  0.15  0.15  0.15  0.15     6  1402
# 2014-12-08  0.11  0.11  0.08  0.08    15  1414
# 2014-12-09  0.09  0.09  0.06  0.07   138  1329
# 2014-12-10  0.05  0.05  0.03  0.04   219  1361
# 2014-12-11  0.07  0.07  0.05  0.05     3  1361
# 2014-12-12  0.04  0.04  0.03  0.03    29  1337
# 2014-12-15  0.02  0.02  0.01  0.01     8  1335
# 2014-12-16  0.03  0.10  0.03  0.04     5  1334
# 2014-12-17  0.03  0.03  0.03  0.03     5  1288
# 2014-12-18  0.04  0.04  0.03  0.04   110  1298
# 2014-12-19  0.04  0.07  0.03  0.06   604  1421
# 2014-12-22  0.03  0.03  0.02  0.02   280  1630
# 2014-12-23  0.01  0.01  0.01  0.01    26  1637, 'file_path': '/home/mad/Options/CBOE/SPY/Weekly/SPY1426L213_D.csv'}
# data dates: <class 'pandas.tseries.index.DatetimeIndex'>
# [2014-11-28, ..., 2014-12-23]
# Length: 18, Freq: None, Timezone: None
# holiday from list: 2014-12-25
# business day: 2014-12-26
# NoData at Timestamp('2014-12-24 00:00:00'): NoData('No option data from the the buy date', (<type 'exceptions.IndexError'>, IndexError('index 0 is out of bounds for axis 0 with size 0',), <traceback object at 0x58f7b00>), datetime.date(2014, 12, 25), <class 'pandas.tseries.index.DatetimeIndex'>
# [2014-11-28, ..., 2014-12-23]
# Length: 18, Freq: None, Timezone: None,                O     H     L     C     V    OI
# timestamp
# 2014-11-28  0.26  0.32  0.25  0.30   201   201
# 2014-12-01  0.24  0.24  0.17  0.17   183   380
# 2014-12-02  0.19  0.19  0.17  0.19  1111  1304
# 2014-12-03  0.20  0.22  0.19  0.22   245  1399
# 2014-12-04  0.15  0.18  0.15  0.17    25  1399
# 2014-12-05  0.15  0.15  0.15  0.15     6  1402
# 2014-12-08  0.11  0.11  0.08  0.08    15  1414
# 2014-12-09  0.09  0.09  0.06  0.07   138  1329
# 2014-12-10  0.05  0.05  0.03  0.04   219  1361
# 2014-12-11  0.07  0.07  0.05  0.05     3  1361
# 2014-12-12  0.04  0.04  0.03  0.03    29  1337
# 2014-12-15  0.02  0.02  0.01  0.01     8  1335
# 2014-12-16  0.03  0.10  0.03  0.04     5  1334
# 2014-12-17  0.03  0.03  0.03  0.03     5  1288
# 2014-12-18  0.04  0.04  0.03  0.04   110  1298
# 2014-12-19  0.04  0.07  0.03  0.06   604  1421
# 2014-12-22  0.03  0.03  0.02  0.02   280  1630
# 2014-12-23  0.01  0.01  0.01  0.01    26  1637)
#
# idx: 2014-12-26 00:00:00
#
# row: {'C': 208.44, 'Buy': True, 'Profit': 0, 'H': 208.84999999999999, 'L': 208.25, 'Decile': 0.020408163265306121, 'volat': 0.0028785261945883434, 'O': 208.31}
#
# next_day: {'C': 208.72, 'Buy': False, 'Profit': 0.0, 'H': 208.97, 'L': 208.13999999999999, 'Decile': 0.12244897959183673, 'volat': 0.0039766193944040466, 'O': 208.22}
#
#
# I: selected option with expiry datetime.date(2015, 1, 16)
# D: round_func: <function nearest_higher at 0x47b9c80>
# I: rounding the strike from 208.22 to 209.0
# D: lower_strikes: [208.0, 207.0, 206.0, 205.0, 204.0, 203.0, 202.0, 201.0, 200.0]
# D: matching_strikes: [209.0]
# D: higher_strikes: [210.0, 211.0, 212.0, 213.0, 214.0, 215.0, 216.0, 217.0, 218.0]
# loading file: /home/mad/Options/CBOE/SPY/Monthly/SPY1517A209_D.csv
# fileinfo: {'load_func': <bound method type.load_func of <class '__main__.OptParserCBOE'>>, 'symbol': 'SPY', 'opt_type': 'C', 'exp_date': datetime.date(2015, 1, 16), 'strike': 209.0, 'file_path': '/home/mad/Options/CBOE/SPY/Monthly/SPY1517A209_D.csv'}
# data dates: <class 'pandas.tseries.index.DatetimeIndex'>
# [2014-09-04, ..., 2015-01-16]
# Length: 93, Freq: None, Timezone: None
# weekend (Saturday): 2014-12-27
# weekend (Sunday): 2014-12-28
# business day: 2014-12-29
# opt_strike:  209.0
# opt_price:  1.99
# ba_price:  201.63
# opt profit:  0.0
# I: selected option with expiry datetime.date(2015, 1, 16)
# D: round_func: <function nearest_higher at 0x47b9c80>
# I: rounding the strike from 208.22 to 209.0
# D: lower_strikes: [208.0, 207.0, 206.0, 205.0, 204.0, 203.0, 202.0, 201.0, 200.0]
# D: matching_strikes: [209.0]
# D: higher_strikes: [210.0, 211.0, 212.0, 213.0, 214.0, 215.0, 216.0, 217.0, 218.0]
# loading file: /home/mad/Options/CBOE/SPY/Monthly/SPY1517A213_D.csv
# fileinfo: {'load_func': <bound method type.load_func of <class '__main__.OptParserCBOE'>>, 'symbol': 'SPY', 'opt_type': 'C', 'exp_date': datetime.date(2015, 1, 16), 'strike': 213.0, 'file_path': '/home/mad/Options/CBOE/SPY/Monthly/SPY1517A213_D.csv'}
# data dates: <class 'pandas.tseries.index.DatetimeIndex'>
# [2014-09-04, ..., 2015-01-16]
# Length: 85, Freq: None, Timezone: None
# weekend (Saturday): 2014-12-27
# weekend (Sunday): 2014-12-28
# business day: 2014-12-29
# opt_strike:  213.0
# opt_price:  0.48
# ba_price:  201.63
# opt profit:  0.0
# I: selected option with expiry datetime.date(2015, 1, 16)
# D: round_func: <function nearest_lower at 0x47b9f50>
# I: rounding the strike from 208.22 to 208.0
# D: lower_strikes: [207.0, 206.0, 205.0, 204.0, 203.0, 202.0, 201.0, 200.0, 199.0]
# D: matching_strikes: [208.0]
# D: higher_strikes: [209.0, 210.0, 211.0, 212.0, 213.0, 214.0, 215.0, 216.0, 217.0]
# loading file: /home/mad/Options/CBOE/SPY/Monthly/SPY1517M208_D.csv
# fileinfo: {'load_func': <bound method type.load_func of <class '__main__.OptParserCBOE'>>, 'symbol': 'SPY', 'opt_type': 'P', 'exp_date': datetime.date(2015, 1, 16), 'strike': 208.0, 'file_path': '/home/mad/Options/CBOE/SPY/Monthly/SPY1517M208_D.csv'}
# data dates: <class 'pandas.tseries.index.DatetimeIndex'>
# [2014-09-05, ..., 2015-01-16]
# Length: 70, Freq: None, Timezone: None
# weekend (Saturday): 2014-12-27
# weekend (Sunday): 2014-12-28
# business day: 2014-12-29
# opt_strike:  208.0
# opt_price:  2.24
# ba_price:  201.63
# opt profit:  0.0
# I: selected option with expiry datetime.date(2015, 1, 16)
# D: round_func: <function nearest_lower at 0x47b9f50>
# I: rounding the strike from 208.22 to 208.0
# D: lower_strikes: [207.0, 206.0, 205.0, 204.0, 203.0, 202.0, 201.0, 200.0, 199.0]
# D: matching_strikes: [208.0]
# D: higher_strikes: [209.0, 210.0, 211.0, 212.0, 213.0, 214.0, 215.0, 216.0, 217.0]
# loading file: /home/mad/Options/CBOE/SPY/Monthly/SPY1517M202_D.csv
# fileinfo: {'load_func': <bound method type.load_func of <class '__main__.OptParserCBOE'>>, 'symbol': 'SPY', 'opt_type': 'P', 'exp_date': datetime.date(2015, 1, 16), 'strike': 202.0, 'file_path': '/home/mad/Options/CBOE/SPY/Monthly/SPY1517M202_D.csv'}
# data dates: <class 'pandas.tseries.index.DatetimeIndex'>
# [2014-09-04, ..., 2015-01-16]
# Length: 88, Freq: None, Timezone: None
# weekend (Saturday): 2014-12-27
# weekend (Sunday): 2014-12-28
# business day: 2014-12-29
# opt_strike:  202.0
# opt_price:  0.88
# ba_price:  201.63
# opt profit:  0.0
#
# res line: {'o3_price': 2.2400000000000002, 'o1_strike': 209.0, 'o4_profit': -0.50999999999999546, 'o2_price': 0.47999999999999998, 'ba_close_price': 201.63, 'ba_on_close_date': Timestamp('2015-01-16 00:00:00'), 'profit': -3.1299999999999999, 'price': Decimal('208.219999999999998863131622783839702606201171875'), 'o4_price': 0.88, 'o3_profit': -4.1300000000000043, 'o3_strike': 208.0, 'o4_strike': 202.0, 'o1_profit': 1.99, 'close_date': datetime.date(2015, 1, 16), 'o1_price': 1.99, 'o2_strike': 213.0, 'o2_profit': -0.47999999999999998}
# I: results length: 93

# %%
#Finalizing ba strategy and save table to excel
pd2f = pd2[pd2['Buy']]
pd3 = pd2f.ix['2014-01-01':'2015-10-01']
pd3 = pd3.drop(['Profit', 'Decile', 'volat','Buy','H', 'L'], 1)
pd3['CumSumm'] = pd3.sum_profit.cumsum()
pd3.to_excel('/home/mad/Options/Results/SPY/Backtests/batterfly_on_0_decile.xlsx')

# %%
H = lambda df: HTML(df.head(400).to_html())
tt = H(pd3)
tt
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>O</th>
#       <th>C</th>
#       <th>close_date</th>
#       <th>ba_on_close</th>
#       <th>call_ATM_strike</th>
#       <th>call_ATM_price</th>
#       <th>call_ATM_profit</th>
#       <th>call_OTM_strike</th>
#       <th>call_OTM_price</th>
#       <th>call_OTM_profit</th>
#       <th>put_ATM_strike</th>
#       <th>put_ATM_price</th>
#       <th>put_ATM_profit</th>
#       <th>put_OTM_strike</th>
#       <th>put_OTM_price</th>
#       <th>put_OTM_profit</th>
#       <th>sum_profit</th>
#       <th>CumSumm</th>
#     </tr>
#     <tr>
#       <th>timestamp</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2014-03-05</th>
#       <td> 187.720</td>
#       <td> 187.750</td>
#       <td> 2014-03-07</td>
#       <td> 188.2600</td>
#       <td> 189</td>
#       <td> 0.32</td>
#       <td> 0.320</td>
#       <td> 193</td>
#       <td> 0.01</td>
#       <td>-0.01</td>
#       <td> 188</td>
#       <td> 0.56</td>
#       <td> 0.56</td>
#       <td> 182</td>
#       <td> 0.03</td>
#       <td>-0.03</td>
#       <td> 0.840</td>
#       <td> 0.840</td>
#     </tr>
#     <tr>
#       <th>2014-04-21</th>
#       <td> 186.440</td>
#       <td> 187.040</td>
#       <td> 2014-04-25</td>
#       <td> 186.2900</td>
#       <td> 188</td>
#       <td> 0.44</td>
#       <td> 0.440</td>
#       <td> 192</td>
#       <td> 0.01</td>
#       <td>-0.01</td>
#       <td> 187</td>
#       <td> 0.72</td>
#       <td> 0.01</td>
#       <td> 181</td>
#       <td> 0.04</td>
#       <td>-0.04</td>
#       <td> 0.400</td>
#       <td> 1.240</td>
#     </tr>
#     <tr>
#       <th>2014-04-23</th>
#       <td> 187.810</td>
#       <td> 187.450</td>
#       <td> 2014-04-25</td>
#       <td> 186.2900</td>
#       <td> 189</td>
#       <td> 0.25</td>
#       <td> 0.250</td>
#       <td> 193</td>
#       <td> 0.01</td>
#       <td>-0.01</td>
#       <td> 188</td>
#       <td> 0.39</td>
#       <td>-1.32</td>
#       <td> 182</td>
#       <td> 0.01</td>
#       <td>-0.01</td>
#       <td>-1.090</td>
#       <td> 0.150</td>
#     </tr>
#     <tr>
#       <th>2014-05-13</th>
#       <td> 190.030</td>
#       <td> 189.960</td>
#       <td> 2014-05-16</td>
#       <td> 188.0500</td>
#       <td> 190</td>
#       <td> 0.57</td>
#       <td> 0.570</td>
#       <td> 194</td>
#       <td> 0.01</td>
#       <td>-0.01</td>
#       <td> 189</td>
#       <td> 0.39</td>
#       <td>-0.56</td>
#       <td> 183</td>
#       <td> 0.03</td>
#       <td>-0.03</td>
#       <td>-0.030</td>
#       <td> 0.120</td>
#     </tr>
#     <tr>
#       <th>2014-05-23</th>
#       <td> 189.750</td>
#       <td> 190.350</td>
#       <td> 2014-05-30</td>
#       <td> 192.6800</td>
#       <td> 192</td>
#       <td> 0.29</td>
#       <td>-0.390</td>
#       <td> 196</td>
#       <td> 0.01</td>
#       <td>-0.01</td>
#       <td> 191</td>
#       <td> 0.74</td>
#       <td> 0.74</td>
#       <td> 185</td>
#       <td> 0.05</td>
#       <td>-0.05</td>
#       <td> 0.290</td>
#       <td> 0.410</td>
#     </tr>
#     <tr>
#       <th>2014-05-27</th>
#       <td> 191.050</td>
#       <td> 191.520</td>
#       <td> 2014-05-30</td>
#       <td> 192.6800</td>
#       <td> 192</td>
#       <td> 0.42</td>
#       <td>-0.260</td>
#       <td> 196</td>
#       <td> 0.01</td>
#       <td>-0.01</td>
#       <td> 191</td>
#       <td> 0.44</td>
#       <td> 0.44</td>
#       <td> 185</td>
#       <td> 0.03</td>
#       <td>-0.03</td>
#       <td> 0.140</td>
#       <td> 0.550</td>
#     </tr>
#     <tr>
#       <th>2014-05-28</th>
#       <td> 191.520</td>
#       <td> 191.380</td>
#       <td> 2014-05-30</td>
#       <td> 192.6800</td>
#       <td> 192</td>
#       <td> 0.35</td>
#       <td>-0.330</td>
#       <td> 196</td>
#       <td> 0.01</td>
#       <td>-0.01</td>
#       <td> 191</td>
#       <td> 0.21</td>
#       <td> 0.21</td>
#       <td> 185</td>
#       <td> 0.01</td>
#       <td>-0.01</td>
#       <td>-0.140</td>
#       <td> 0.410</td>
#     </tr>
#     <tr>
#       <th>2014-05-30</th>
#       <td> 192.190</td>
#       <td> 192.680</td>
#       <td> 2014-06-06</td>
#       <td> 195.3750</td>
#       <td> 193</td>
#       <td> 0.75</td>
#       <td>-1.625</td>
#       <td> 197</td>
#       <td> 0.02</td>
#       <td>-0.02</td>
#       <td> 192</td>
#       <td> 0.50</td>
#       <td> 0.50</td>
#       <td> 186</td>
#       <td> 0.05</td>
#       <td>-0.05</td>
#       <td>-1.195</td>
#       <td>-0.785</td>
#     </tr>
#     <tr>
#       <th>2014-06-03</th>
#       <td> 192.400</td>
#       <td> 192.800</td>
#       <td> 2014-06-06</td>
#       <td> 195.3750</td>
#       <td> 193</td>
#       <td> 0.52</td>
#       <td>-1.855</td>
#       <td> 197</td>
#       <td> 0.01</td>
#       <td>-0.01</td>
#       <td> 192</td>
#       <td> 0.61</td>
#       <td> 0.61</td>
#       <td> 186</td>
#       <td> 0.03</td>
#       <td>-0.03</td>
#       <td>-1.285</td>
#       <td>-2.070</td>
#     </tr>
#     <tr>
#       <th>2014-06-06</th>
#       <td> 194.870</td>
#       <td> 195.375</td>
#       <td> 2014-06-13</td>
#       <td> 194.1300</td>
#       <td> 196</td>
#       <td> 0.45</td>
#       <td> 0.450</td>
#       <td> 200</td>
#       <td> 0.02</td>
#       <td>-0.02</td>
#       <td> 195</td>
#       <td> 0.64</td>
#       <td>-0.23</td>
#       <td> 189</td>
#       <td> 0.04</td>
#       <td>-0.04</td>
#       <td> 0.160</td>
#       <td>-1.910</td>
#     </tr>
#     <tr>
#       <th>2014-06-11</th>
#       <td> 194.900</td>
#       <td> 194.920</td>
#       <td> 2014-06-13</td>
#       <td> 194.1300</td>
#       <td> 195</td>
#       <td> 0.36</td>
#       <td> 0.360</td>
#       <td> 199</td>
#       <td> 0.01</td>
#       <td>-0.01</td>
#       <td> 194</td>
#       <td> 0.26</td>
#       <td> 0.26</td>
#       <td> 188</td>
#       <td> 0.01</td>
#       <td>-0.01</td>
#       <td> 0.600</td>
#       <td>-1.310</td>
#     </tr>
#     <tr>
#       <th>2014-06-20</th>
#       <td> 196.030</td>
#       <td> 195.940</td>
#       <td> 2014-06-27</td>
#       <td> 195.8200</td>
#       <td> 196</td>
#       <td> 0.71</td>
#       <td> 0.710</td>
#       <td> 200</td>
#       <td> 0.01</td>
#       <td>-0.01</td>
#       <td> 195</td>
#       <td> 0.44</td>
#       <td> 0.44</td>
#       <td> 189</td>
#       <td> 0.07</td>
#       <td>-0.07</td>
#       <td> 1.070</td>
#       <td>-0.240</td>
#     </tr>
#     <tr>
#       <th>2014-06-23</th>
#       <td> 195.970</td>
#       <td> 195.880</td>
#       <td> 2014-06-27</td>
#       <td> 195.8200</td>
#       <td> 196</td>
#       <td> 0.39</td>
#       <td> 0.390</td>
#       <td> 200</td>
#       <td> 0.01</td>
#       <td>-0.01</td>
#       <td> 195</td>
#       <td> 0.46</td>
#       <td> 0.46</td>
#       <td> 189</td>
#       <td> 0.04</td>
#       <td>-0.04</td>
#       <td> 0.800</td>
#       <td> 0.560</td>
#     </tr>
#     <tr>
#       <th>2014-06-30</th>
#       <td> 195.700</td>
#       <td> 195.720</td>
#       <td> 2014-07-03</td>
#       <td> 198.2000</td>
#       <td> 197</td>
#       <td> 0.17</td>
#       <td>-1.030</td>
#       <td> 205</td>
#       <td> 0.01</td>
#       <td>-0.01</td>
#       <td> 196</td>
#       <td> 0.52</td>
#       <td> 0.52</td>
#       <td> 190</td>
#       <td> 0.05</td>
#       <td>-0.05</td>
#       <td>-0.570</td>
#       <td>-0.010</td>
#     </tr>
#     <tr>
#       <th>2014-07-02</th>
#       <td> 197.050</td>
#       <td> 197.230</td>
#       <td>        NaN</td>
#       <td>      NaN</td>
#       <td> NaN</td>
#       <td>  NaN</td>
#       <td>   NaN</td>
#       <td> NaN</td>
#       <td>  NaN</td>
#       <td>  NaN</td>
#       <td> NaN</td>
#       <td>  NaN</td>
#       <td>  NaN</td>
#       <td> NaN</td>
#       <td>  NaN</td>
#       <td>  NaN</td>
#       <td>   NaN</td>
#       <td>   NaN</td>
#     </tr>
#     <tr>
#       <th>2014-07-03</th>
#       <td> 197.790</td>
#       <td> 198.200</td>
#       <td>        NaN</td>
#       <td>      NaN</td>
#       <td> NaN</td>
#       <td>  NaN</td>
#       <td>   NaN</td>
#       <td> NaN</td>
#       <td>  NaN</td>
#       <td>  NaN</td>
#       <td> NaN</td>
#       <td>  NaN</td>
#       <td>  NaN</td>
#       <td> NaN</td>
#       <td>  NaN</td>
#       <td>  NaN</td>
#       <td>   NaN</td>
#       <td>   NaN</td>
#     </tr>
#     <tr>
#       <th>2014-07-14</t

# %%
from pybacktest.performance import performance_summary
performance_summary(pd3.sum_profit)
# Out:
# {'backtest': {'days': 296,
#   'from': '2014-03-05 00:00:00',
#   'to': '2014-12-26 00:00:00',
#   'trades': 31},
#  'exposure': {'trades/month': 3.0},
#  'performance': {'PF': 0.683,
#   'RF': -0.4955,
#   'averages': {'gain': 0.6786, 'loss': -1.391, 'trade': -0.1838},
#   'payoff': 0.4878,
#   'profit': -4.41,
#   'winrate': 0.4516},
#  'risk/return profile': {'MPI': -0.279,
#   'UPI': -0.0814,
#   'WCDD (monte-carlo 0.99 quantile)': 11.8602,
#   'maxdd': 8.9,
#   'sharpe': -0.1307,
#   'sortino': -0.1262}}

# %%
pd3.sum_profit.cumsum().plot()
